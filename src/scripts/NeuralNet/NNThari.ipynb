# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import os
import imblearn

# %%
main_dir = 'C:/Users/Tharindu/Desktop/Professional development/Competitions/Datastorm2021/datastorm-2021/'

# %%
data_dir = main_dir+'data/feature/'
train_file = data_dir+'cbasi_train.csv'
val_file = data_dir+'cbasi_validation.csv'
test_file = data_dir+'cbasi_test.csv'
NN_dir = main_dir+'src/scripts/NeuralNet/'

# %%
train_ds = pd.read_csv(train_file)
val_ds = pd.read_csv(val_file)

# %%
def start_category_from_zero(df,columns):
    for each in columns:
        df[each] = df[each] - 1

    return df

# %%
start_category_from_zero(train_ds,['Reservation_Status'])
start_category_from_zero(val_ds,['Reservation_Status'])
# Out:
#            Age  Ethnicity  Educational_Level    Income  Meal_Type  \
# 0     0.785640  -0.017315          -0.001419  0.007453   0.145374
# 1     1.047029   0.010376          -0.003171  0.012407   0.622649
# 2     0.916334  -0.009340          -0.003171  0.007453   0.622649
# 3    -1.370818   0.010376          -0.003171  0.012407   0.622649
# 4     0.197515  -0.009340          -0.003171  0.012407   0.145374
# ...        ...        ...                ...       ...        ...
# 2744 -1.436166  -0.017315          -0.003171 -0.012088  -0.444474
# 2745 -0.586652  -0.017315          -0.003171  0.012407   0.622649
# 2746 -1.697554  -0.009340          -0.001419  0.012407   0.622649
# 2747 -0.129221  -0.009340          -0.003171  0.007453   0.145374
# 2748  0.589598   0.014371           0.002616 -0.012970   0.145374
#
#       Visted_Previously  Previous_Cancellations  Deposit_type  \
# 0              0.010791                0.003794      0.022095
# 1             -0.021917                0.003794      0.022095
# 2              0.010791                0.003794      0.022095
# 3             -0.021917                0.003794     -0.069188
# 4             -0.021917                0.003794      0.022095
# ...                 ...                     ...           ...
# 2744          -0.021917                0.003794     -0.069188
# 2745           0.010791                0.003794      0.025248
# 2746           0.010791                0.003794     -0.069188
# 2747          -0.021917               -0.030540      0.022095
# 2748           0.010791                0.003794     -0.069188
#
#       Required_Car_Parking  Use_Promotion  Room_Rate  month_Expected_checkin  \
# 0                -0.014993       0.004285   0.384342                       8
# 1                 0.005952      -0.013100   0.270386                       8
# 2                -0.014993       0.004285   1.182040                       9
# 3                -0.014993       0.004285   0.315968                       8
# 4                 0.005952       0.004285   0.976918                       8
# ...                    ...            ...        ...                     ...
# 2744             -0.014993       0.004285   0.543882                      11
# 2745              0.005952       0.004285  -1.575714                      12
# 2746             -0.014993       0.004285  -0.891973                      11
# 2747              0.005952       0.004285   1.159249                      11
# 2748             -0.014993       0.004285   0.179220                      11
#
#       dayofweek_Expected_checkin  stay  total_participants  Reservation_Status
# 0                              2     2                   4                   2
# 1                              2     4                   4                   1
# 2                              3     1                   4                   1
# 3                              2     2                   3                   0
# 4                              2     1                   2                   0
# ...                          ...   ...                 ...                 ...
# 2744                           4     3                   7                   0
# 2745                           4     1                   5                   1
# 2746                           4     2                   5                   2
# 2747                           4     1                   6                   0
# 2748                           4     3                   6                   0
#
# [2749 rows x 16 columns]

# %%
print(train_ds['Reservation_Status'].value_counts())
train_ds.dtypes
# Out:
# 0    21240
# 1    21240
# 2    21240
# Name: Reservation_Status, dtype: int64
# Age                           float64
# Ethnicity                     float64
# Educational_Level             float64
# Income                        float64
# Meal_Type                     float64
# Visted_Previously             float64
# Previous_Cancellations        float64
# Deposit_type                  float64
# Required_Car_Parking          float64
# Use_Promotion                 float64
# Room_Rate                     float64
# month_Expected_checkin          int64
# dayofweek_Expected_checkin      int64
# stay                            int64
# total_participants              int64
# Reservation_Status              int64
# dtype: object

# %%
x_columns = [x for x in train_ds.columns if x != 'Reservation_Status']
y_columns = ['Reservation_Status']
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name='Adam'
)
batch_size = 64
input_shape = (len(x_columns))
epochs = 200
print(input_shape)
# Out:
# 15

# %%
x_columns
# Out:
# ['Age',
#  'Ethnicity',
#  'Educational_Level',
#  'Income',
#  'Meal_Type',
#  'Visted_Previously',
#  'Previous_Cancellations',
#  'Deposit_type',
#  'Required_Car_Parking',
#  'Use_Promotion',
#  'Room_Rate',
#  'month_Expected_checkin',
#  'dayofweek_Expected_checkin',
#  'stay',
#  'total_participants']

# %%
x_train = np.asarray(train_ds[x_columns])
y_train = np.asarray(train_ds[y_columns])
x_val = np.asarray(val_ds[x_columns])
y_val = np.asarray(val_ds[y_columns])

# %%
x_train.shape
# Out:
# (63720, 15)

# %%
y_train.shape
# Out:
# (63720, 1)

# %%
#from imblearn.over_sampling import SMOTE
#sm = SMOTE(random_state=0)
#x_sm, y_train = sm.fit_resample(x_train, y_train)
#x_train = pd.DataFrame(x_sm,columns=x_columns)

# %%
x_train.shape
# Out:
# (63720, 15)

# %%
y_train.shape
# Out:
# (63720, 1)

# %%
from functools import partial
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=input_shape))
model.add(tf.keras.layers.Dense(100,activation='tanh'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(150,activation=partial(tf.nn.leaky_relu, alpha=0.01)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(180,activation='tanh'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(150,activation='tanh'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 100)               1600
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 100)               400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 150)               15150
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 150)               600
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 180)               27180
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 180)               720
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 180)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 150)               27150
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 150)               600
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 453
# =================================================================
# Total params: 73,853
# Trainable params: 72,693
# Non-trainable params: 1,160
# _________________________________________________________________

# %%
def func(x):
    return x.argmax()

# %%
import numpy as np
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

validation_data = (x_val,y_val)

class Metrics(Callback):
    def on_train_begin(self,logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
        

    def on_epoch_end(self, epoch, logs={}):
        val_predict = (np.asarray(self.model.predict(
            validation_data[0])))
        val_predict = np.apply_along_axis(func, 1, val_predict)
        val_targ = validation_data[1]
        _val_f1 = f1_score(val_targ, val_predict,average='macro')
        _val_recall = recall_score(val_targ, val_predict,average='macro')
        _val_precision = precision_score(val_targ, val_predict,average='macro')
        self.val_f1s.append(_val_f1)
        self.val_recalls.append(_val_recall)
        self.val_precisions.append(_val_precision)
        print(f" — val_f1: {_val_f1} — val_precision: {_val_precision} — val_recall _val_recall")
        return


metrics = Metrics()

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer= optimizer,
    metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train ,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data = validation_data,
                    callbacks=[metrics])
# Out:
# ccuracy: 0.4598
#  — val_f1: 0.31059581690721805 — val_precision: 0.3223699610614689 — val_recall _val_recall
# Epoch 117/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9429 - accuracy: 0.4996 - val_loss: 1.0401 - val_accuracy: 0.4925
#  — val_f1: 0.3112746826940942 — val_precision: 0.3426450494522562 — val_recall _val_recall
# Epoch 118/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9429 - accuracy: 0.5024 - val_loss: 1.0388 - val_accuracy: 0.4958
#  — val_f1: 0.3422294151438532 — val_precision: 0.3556721770172749 — val_recall _val_recall
# Epoch 119/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9412 - accuracy: 0.5007 - val_loss: 1.0501 - val_accuracy: 0.4962
#  — val_f1: 0.3331030278370216 — val_precision: 0.34329116068300985 — val_recall _val_recall
# Epoch 120/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9411 - accuracy: 0.5015 - val_loss: 1.0474 - val_accuracy: 0.4965
#  — val_f1: 0.34801857065444525 — val_precision: 0.3575352208229297 — val_recall _val_recall
# Epoch 121/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9400 - accuracy: 0.5031 - val_loss: 1.0310 - val_accuracy: 0.5009
#  — val_f1: 0.32039205996554443 — val_precision: 0.34967319373005595 — val_recall _val_recall
# Epoch 122/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9363 - accuracy: 0.5052 - val_loss: 1.0444 - val_accuracy: 0.4940
#  — val_f1: 0.3322168607130838 — val_precision: 0.3433783001962465 — val_recall _val_recall
# Epoch 123/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9403 - accuracy: 0.5044 - val_loss: 1.0421 - val_accuracy: 0.4471
#  — val_f1: 0.32696761316043615 — val_precision: 0.3330757364621941 — val_recall _val_recall
# Epoch 124/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9407 - accuracy: 0.5038 - val_loss: 1.0365 - val_accuracy: 0.4958
#  — val_f1: 0.34275834640892633 — val_precision: 0.35297576475208575 — val_recall _val_recall
# Epoch 125/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9402 - accuracy: 0.5046 - val_loss: 1.0810 - val_accuracy: 0.4958
#  — val_f1: 0.34296773432956495 — val_precision: 0.3526480712003608 — val_recall _val_recall
# Epoch 126/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9424 - accuracy: 0.5002 - val_loss: 1.0373 - val_accuracy: 0.4922
#  — val_f1: 0.3324284468076268 — val_precision: 0.3466900747002451 — val_recall _val_recall
# Epoch 127/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9393 - accuracy: 0.5022 - val_loss: 1.0353 - val_accuracy: 0.5118
#  — val_f1: 0.32816243814547474 — val_precision: 0.3605010852426982 — val_recall _val_recall
# Epoch 128/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9404 - accuracy: 0.5042 - val_loss: 1.0254 - val_accuracy: 0.5053
#  — val_f1: 0.31710490101526556 — val_precision: 0.35332666582666583 — val_recall _val_recall
# Epoch 129/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9390 - accuracy: 0.5062 - val_loss: 1.0322 - val_accuracy: 0.5133
#  — val_f1: 0.3160610475903192 — val_precision: 0.3556671682090524 — val_recall _val_recall
# Epoch 130/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9413 - accuracy: 0.5022 - val_loss: 1.0189 - val_accuracy: 0.5311
#  — val_f1: 0.3045071908446715 — val_precision: 0.3532820497947518 — val_recall _val_recall
# Epoch 131/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9381 - accuracy: 0.5050 - val_loss: 1.0221 - val_accuracy: 0.5187
#  — val_f1: 0.32477963635775636 — val_precision: 0.3520561655889227 — val_recall _val_recall
# Epoch 132/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9397 - accuracy: 0.5030 - val_loss: 1.0342 - val_accuracy: 0.5027
#  — val_f1: 0.31531763929936 — val_precision: 0.33641025569911287 — val_recall _val_recall
# Epoch 133/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9436 - accuracy: 0.5018 - val_loss: 1.0303 - val_accuracy: 0.4933
#  — val_f1: 0.3141234131225716 — val_precision: 0.34642712862678576 — val_recall _val_recall
# Epoch 134/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9391 - accuracy: 0.5046 - val_loss: 1.0337 - val_accuracy: 0.5020
#  — val_f1: 0.3178360906910254 — val_precision: 0.3399848763926274 — val_recall _val_recall
# Epoch 135/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9432 - accuracy: 0.5030 - val_loss: 1.0202 - val_accuracy: 0.5198
#  — val_f1: 0.3301119130646339 — val_precision: 0.3606849255913032 — val_recall _val_recall
# Epoch 136/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9354 - accuracy: 0.5056 - val_loss: 1.0447 - val_accuracy: 0.4503
#  — val_f1: 0.3443417446528114 — val_precision: 0.34833790493233446 — val_recall _val_recall
# Epoch 137/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9425 - accuracy: 0.5035 - val_loss: 1.0232 - val_accuracy: 0.5224
#  — val_f1: 0.3291248985268028 — val_precision: 0.35148379082693065 — val_recall _val_recall
# Epoch 138/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9376 - accuracy: 0.5080 - val_loss: 1.0459 - val_accuracy: 0.4758
#  — val_f1: 0.31651393274237055 — val_precision: 0.3515378444281303 — val_recall _val_recall
# Epoch 139/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9394 - accuracy: 0.5044 - val_loss: 1.0353 - val_accuracy: 0.5035
#  — val_f1: 0.32743475552499934 — val_precision: 0.3600764460369101 — val_recall _val_recall
# Epoch 140/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9359 - accuracy: 0.5070 - val_loss: 1.0282 - val_accuracy: 0.4984
#  — val_f1: 0.3079061459450052 — val_precision: 0.3472817063756437 — val_recall _val_recall
# Epoch 141/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9339 - accuracy: 0.5098 - val_loss: 1.0442 - val_accuracy: 0.5013
#  — val_f1: 0.3245169230498822 — val_precision: 0.3427476130750234 — val_recall _val_recall
# Epoch 142/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9396 - accuracy: 0.5004 - val_loss: 1.0518 - val_accuracy: 0.4878
#  — val_f1: 0.30924366171160195 — val_precision: 0.344457348980356 — val_recall _val_recall
# Epoch 143/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9410 - accuracy: 0.5026 - val_loss: 1.0177 - val_accuracy: 0.5206
#  — val_f1: 0.3177334701697893 — val_precision: 0.34333804764454806 — val_recall _val_recall
# Epoch 144/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9405 - accuracy: 0.5024 - val_loss: 1.0311 - val_accuracy: 0.5111
#  — val_f1: 0.3211505759489508 — val_precision: 0.35012016148818986 — val_recall _val_recall
# Epoch 145/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9382 - accuracy: 0.5061 - val_loss: 1.0268 - val_accuracy: 0.5056
#  — val_f1: 0.3149074777852635 — val_precision: 0.3493163938596759 — val_recall _val_recall
# Epoch 146/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9367 - accuracy: 0.5062 - val_loss: 1.0391 - val_accuracy: 0.4976
#  — val_f1: 0.31967978868401176 — val_precision: 0.3457156283327328 — val_recall _val_recall
# Epoch 147/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9381 - accuracy: 0.5052 - val_loss: 1.0593 - val_accuracy: 0.4769
#  — val_f1: 0.3274052503951998 — val_precision: 0.33975267427885747 — val_recall _val_recall
# Epoch 148/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9418 - accuracy: 0.5024 - val_loss: 1.0371 - val_accuracy: 0.5071
#  — val_f1: 0.32735623416147663 — val_precision: 0.34768188873999334 — val_recall _val_recall
# Epoch 149/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9371 - accuracy: 0.5044 - val_loss: 1.0428 - val_accuracy: 0.4813
#  — val_f1: 0.3408062208816864 — val_precision: 0.34849355268880267 — val_recall _val_recall
# Epoch 150/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9384 - accuracy: 0.5064 - val_loss: 1.0472 - val_accuracy: 0.4853
#  — val_f1: 0.3136417721745937 — val_precision: 0.3569996834227011 — val_recall _val_recall
# Epoch 151/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9340 - accuracy: 0.5090 - val_loss: 1.0436 - val_accuracy: 0.4842
#  — val_f1: 0.3248802659338765 — val_precision: 0.3443009175919771 — val_recall _val_recall
# Epoch 152/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9394 - accuracy: 0.5049 - val_loss: 1.0371 - val_accuracy: 0.4965
#  — val_f1: 0.3211458687078641 — val_precision: 0.3438243154184557 — val_recall _val_recall
# Epoch 153/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9426 - accuracy: 0.5041 - val_loss: 1.0267 - val_accuracy: 0.5144
#  — val_f1: 0.30828918331848915 — val_precision: 0.3589247003498308 — val_recall _val_recall
# Epoch 154/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9374 - accuracy: 0.5035 - val_loss: 1.0422 - val_accuracy: 0.4831
#  — val_f1: 0.2997005978740975 — val_precision: 0.357070990854395 — val_recall _val_recall
# Epoch 155/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9378 - accuracy: 0.5063 - val_loss: 1.0396 - val_accuracy: 0.5053
#  — val_f1: 0.3388525787825263 — val_precision: 0.3529032713347637 — val_recall _val_recall
# Epoch 156/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9396 - accuracy: 0.5038 - val_loss: 1.0407 - val_accuracy: 0.4882
#  — val_f1: 0.34643264405515595 — val_precision: 0.35399353282564966 — val_recall _val_recall
# Epoch 157/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9386 - accuracy: 0.5029 - val_loss: 1.0249 - val_accuracy: 0.5085
#  — val_f1: 0.3392444823694824 — val_precision: 0.35568940531464416 — val_recall _val_recall
# Epoch 158/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9396 - accuracy: 0.5035 - val_loss: 1.0568 - val_accuracy: 0.4744
#  — val_f1: 0.32968676927629487 — val_precision: 0.3401801320985984 — val_recall _val_recall
# Epoch 159/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9352 - accuracy: 0.5076 - val_loss: 1.0130 - val_accuracy: 0.5275
#  — val_f1: 0.32564772222311106 — val_precision: 0.35257401363174146 — val_recall _val_recall
# Epoch 160/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9331 - accuracy: 0.5060 - val_loss: 1.0376 - val_accuracy: 0.4834
#  — val_f1: 0.3264346761500224 — val_precision: 0.339610638667005 — val_recall _val_recall
# Epoch 161/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9368 - accuracy: 0.5073 - val_loss: 1.0632 - val_accuracy: 0.4693
#  — val_f1: 0.32733184576816293 — val_precision: 0.33157286829270793 — val_recall _val_recall
# Epoch 162/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9385 - accuracy: 0.5053 - val_loss: 1.0283 - val_accuracy: 0.5231
#  — val_f1: 0.3196570820671303 — val_precision: 0.34594026069699524 — val_recall _val_recall
# Epoch 163/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9402 - accuracy: 0.5034 - val_loss: 1.0277 - val_accuracy: 0.5085
#  — val_f1: 0.3218535037525193 — val_precision: 0.34321187399186986 — val_recall _val_recall
# Epoch 164/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9369 - accuracy: 0.5058 - val_loss: 1.0395 - val_accuracy: 0.4911
#  — val_f1: 0.32193353663869223 — val_precision: 0.3355415938528936 — val_recall _val_recall
# Epoch 165/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9353 - accuracy: 0.5069 - val_loss: 1.0465 - val_accuracy: 0.4816
#  — val_f1: 0.3079621701605751 — val_precision: 0.3393099742042957 — val_recall _val_recall
# Epoch 166/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9346 - accuracy: 0.5083 - val_loss: 1.0416 - val_accuracy: 0.4951
#  — val_f1: 0.3080834850575463 — val_precision: 0.3411836952417495 — val_recall _val_recall
# Epoch 167/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9386 - accuracy: 0.5048 - val_loss: 1.0355 - val_accuracy: 0.4976
#  — val_f1: 0.3243034214519351 — val_precision: 0.3454072494156471 — val_recall _val_recall
# Epoch 168/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9369 - accuracy: 0.5039 - val_loss: 1.0333 - val_accuracy: 0.5005
#  — val_f1: 0.3257804218342653 — val_precision: 0.34522231616974763 — val_recall _val_recall
# Epoch 169/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9393 - accuracy: 0.5069 - val_loss: 1.0418 - val_accuracy: 0.4762
#  — val_f1: 0.3151848764316932 — val_precision: 0.34569880318693436 — val_recall _val_recall
# Epoch 170/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9370 - accuracy: 0.5109 - val_loss: 1.0126 - val_accuracy: 0.5235
#  — val_f1: 0.3250556466872015 — val_precision: 0.3510117762938714 — val_recall _val_recall
# Epoch 171/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9396 - accuracy: 0.5082 - val_loss: 1.0368 - val_accuracy: 0.4940
#  — val_f1: 0.34802352945896087 — val_precision: 0.3581939022123071 — val_recall _val_recall
# Epoch 172/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9347 - accuracy: 0.5118 - val_loss: 1.0303 - val_accuracy: 0.5056
#  — val_f1: 0.34035970709615987 — val_precision: 0.35386117360517694 — val_recall _val_recall
# Epoch 173/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9400 - accuracy: 0.4998 - val_loss: 1.0359 - val_accuracy: 0.4864
#  — val_f1: 0.3211828330762457 — val_precision: 0.3499432797865891 — val_recall _val_recall
# Epoch 174/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9404 - accuracy: 0.5025 - val_loss: 1.0400 - val_accuracy: 0.5056
#  — val_f1: 0.32708277222114374 — val_precision: 0.34563379150743295 — val_recall _val_recall
# Epoch 175/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9389 - accuracy: 0.5050 - val_loss: 1.0463 - val_accuracy: 0.4944
#  — val_f1: 0.31831314016218776 — val_precision: 0.3471838947119186 — val_recall _val_recall
# Epoch 176/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9362 - accuracy: 0.5087 - val_loss: 1.0503 - val_accuracy: 0.4754
#  — val_f1: 0.31268445725356814 — val_precision: 0.3427139626533295 — val_recall _val_recall
# Epoch 177/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9349 - accuracy: 0.5097 - val_loss: 1.0278 - val_accuracy: 0.5038
#  — val_f1: 0.3269208984048037 — val_precision: 0.3549659729291558 — val_recall _val_recall
# Epoch 178/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9368 - accuracy: 0.5009 - val_loss: 1.5894 - val_accuracy: 0.3925
#  — val_f1: 0.31241912421769097 — val_precision: 0.3435217046768653 — val_recall _val_recall
# Epoch 179/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9373 - accuracy: 0.5072 - val_loss: 1.0386 - val_accuracy: 0.4904
#  — val_f1: 0.33352421669062243 — val_precision: 0.34439227015737833 — val_recall _val_recall
# Epoch 180/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9349 - accuracy: 0.5098 - val_loss: 1.0452 - val_accuracy: 0.4980
#  — val_f1: 0.3194823338278106 — val_precision: 0.3505271823479628 — val_recall _val_recall
# Epoch 181/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9405 - accuracy: 0.5059 - val_loss: 1.0377 - val_accuracy: 0.5009
#  — val_f1: 0.3291872603730584 — val_precision: 0.35177938201528947 — val_recall _val_recall
# Epoch 182/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9334 - accuracy: 0.5088 - val_loss: 1.0410 - val_accuracy: 0.4882
#  — val_f1: 0.33207380820916416 — val_precision: 0.35755102013833656 — val_recall _val_recall
# Epoch 183/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9351 - accuracy: 0.5053 - val_loss: 1.0374 - val_accuracy: 0.4973
#  — val_f1: 0.32099588741401186 — val_precision: 0.3481946412904096 — val_recall _val_recall
# Epoch 184/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9384 - accuracy: 0.5038 - val_loss: 1.0406 - val_accuracy: 0.4929
#  — val_f1: 0.32101187100025236 — val_precision: 0.3404380997302108 — val_recall _val_recall
# Epoch 185/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9383 - accuracy: 0.5079 - val_loss: 1.0303 - val_accuracy: 0.5060
#  — val_f1: 0.32460361207131494 — val_precision: 0.34474244840501006 — val_recall _val_recall
# Epoch 186/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9373 - accuracy: 0.5085 - val_loss: 1.0291 - val_accuracy: 0.5009
#  — val_f1: 0.3400716111908812 — val_precision: 0.35311817738364604 — val_recall _val_recall
# Epoch 187/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9333 - accuracy: 0.5092 - val_loss: 1.0349 - val_accuracy: 0.4991
#  — val_f1: 0.32040608665804843 — val_precision: 0.3462952103998988 — val_recall _val_recall
# Epoch 188/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9316 - accuracy: 0.5111 - val_loss: 1.0331 - val_accuracy: 0.5056
#  — val_f1: 0.3216933557640367 — val_precision: 0.35429892854547407 — val_recall _val_recall
# Epoch 189/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9317 - accuracy: 0.5100 - val_loss: 1.0505 - val_accuracy: 0.4656
#  — val_f1: 0.31371694306928133 — val_precision: 0.3557141166403816 — val_recall _val_recall
# Epoch 190/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9344 - accuracy: 0.5119 - val_loss: 1.0236 - val_accuracy: 0.5107
#  — val_f1: 0.3145500016353352 — val_precision: 0.34301448502724513 — val_recall _val_recall
# Epoch 191/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9321 - accuracy: 0.5084 - val_loss: 1.0413 - val_accuracy: 0.5024
#  — val_f1: 0.32258584000451607 — val_precision: 0.3459181072241329 — val_recall _val_recall
# Epoch 192/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9362 - accuracy: 0.5072 - val_loss: 1.0396 - val_accuracy: 0.4871
#  — val_f1: 0.32514147145003486 — val_precision: 0.3368867120165959 — val_recall _val_recall
# Epoch 193/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9347 - accuracy: 0.5094 - val_loss: 1.0287 - val_accuracy: 0.5009
#  — val_f1: 0.30824668948971506 — val_precision: 0.33595190069111885 — val_recall _val_recall
# Epoch 194/200
# 996/996 [==============================] - 4s 4ms/step - loss: 0.9325 - accuracy: 0.5099 - val_loss: 1.0256 - val_accuracy: 0.5166
#  — val_f1: 0.31515628825880854 — val_precision: 0.3493776209244685 — val_recall _val_recall
# Epoch 195/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9353 - accuracy: 0.5099 - val_loss: 1.0372 - val_accuracy: 0.4900
#  — val_f1: 0.32967916639215505 — val_precision: 0.35388527323933094 — val_recall _val_recall
# Epoch 196/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9318 - accuracy: 0.5088 - val_loss: 1.0276 - val_accuracy: 0.5176
#  — val_f1: 0.31711965376518286 — val_precision: 0.3514483944025361 — val_recall _val_recall
# Epoch 197/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9353 - accuracy: 0.5112 - val_loss: 1.0414 - val_accuracy: 0.4925
#  — val_f1: 0.33163917533202186 — val_precision: 0.3440690075810504 — val_recall _val_recall
# Epoch 198/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9324 - accuracy: 0.5089 - val_loss: 1.0469 - val_accuracy: 0.4995
#  — val_f1: 0.32028205917810976 — val_precision: 0.3392923097216726 — val_recall _val_recall
# Epoch 199/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9356 - accuracy: 0.5051 - val_loss: 1.0237 - val_accuracy: 0.5176
#  — val_f1: 0.3150508370228516 — val_precision: 0.3542594650641751 — val_recall _val_recall
# Epoch 200/200
# 996/996 [==============================] - 3s 3ms/step - loss: 0.9345 - accuracy: 0.5079 - val_loss: 1.0264 - val_accuracy: 0.5242
#  — val_f1: 0.31879476109962157 — val_precision: 0.3624874116686197 — val_recall _val_recall

# %%
prediction_val = model.predict(x_val)
prediction_train  = model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
prediction_train = np.apply_along_axis(func, 1, prediction_train)
prediction_val = np.apply_along_axis(func, 1, prediction_val)

# %%
y_train
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [2],
#        [2],
#        [2]], dtype=int64)

# %%
stats =  {
    'train' : {
        'accuracy' : accuracy_score(y_train, prediction_train),
        'precision' : precision_score(y_train,prediction_train, average='macro'),
        'recall' : recall_score(y_train, prediction_train, average='macro'),
        'f1-score' : f1_score(y_train, prediction_train, average='macro')},
    'test' : {
        'accuracy' : accuracy_score(y_val, prediction_val),
        'precision' : precision_score(y_val, prediction_val, average='macro'),
        'recall' : recall_score(y_val, prediction_val, average='macro'),
        'f1-score' : f1_score(y_val, prediction_val, average='macro')
    }
}

# %%
print(stats)
with open(NN_dir+'score_BEFOREencode_cb.json','w') as pf:
    json.dump(stats, pf)
# Out:
# {'train': {'accuracy': 0.5216729441305713, 'precision': 0.525489206046937, 'recall': 0.5216729441305713, 'f1-score': 0.4826542105417169}, 'test': {'accuracy': 0.5241906147690069, 'precision': 0.3624874116686197, 'recall': 0.34680897579601627, 'f1-score': 0.31879476109962157}}

# %%
import matplotlib.pyplot as plt
def acc_n_loss(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    with open("metrics.json", 'w') as outfile:
        json.dump({"Training-accuracy": acc[-1], "Validation-accuracy": val_acc[-1], "Training-loss": loss[-1],
                   "Validation-loss": val_loss[-1]}, outfile)

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')

    plt.figure()

    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
acc_n_loss(history)

# %%
test_ds = pd.read_csv(test_file)

# %%
test_ds
# Out:
#       Reservation-id       Age  Ethnicity  Educational_Level    Income  \
# 0           62931593  0.524251   0.010376          -0.001419  0.012407
# 1           70586099  0.197515   0.010376          -0.001419  0.012407
# 2            4230648 -1.044082  -0.009340          -0.001419  0.007453
# 3           25192322  1.373765  -0.017315           0.002616  0.012407
# 4           80931528  0.066821   0.014371          -0.003171  0.012407
# ...              ...       ...        ...                ...       ...
# 4313        39110574  0.589598   0.010376          -0.003171 -0.012088
# 4314         5496554  1.243071  -0.017315          -0.003171 -0.012088
# 4315        59004046  0.981682  -0.017315          -0.001419  0.007453
# 4316        65838682 -0.063874   0.014371          -0.003171  0.012407
# 4317        14474101 -0.717346   0.014371           0.006746 -0.012088
#
#       Meal_Type  Visted_Previously  Previous_Cancellations  Deposit_type  \
# 0      0.145374           0.010791                0.003794      0.022095
# 1      0.622649           0.010791                0.003794      0.022095
# 2     -0.444474           0.010791                0.003794      0.022095
# 3      0.622649           0.010791                0.003794      0.022095
# 4     -0.444474           0.010791                0.003794     -0.069188
# ...         ...                ...                     ...           ...
# 4313   0.622649          -0.021917                0.003794      0.025248
# 4314   0.145374           0.010791                0.003794     -0.069188
# 4315   0.622649           0.010791                0.003794      0.022095
# 4316  -0.444474           0.010791                0.003794      0.022095
# 4317   0.145374          -0.021917                0.003794      0.022095
#
#       Required_Car_Parking  Use_Promotion  Room_Rate  month_Expected_checkin  \
# 0                 0.005952       0.004285  -0.504520                      11
# 1                -0.014993      -0.013100   0.794587                      11
# 2                -0.014993       0.004285  -1.325009                       4
# 3                 0.005952       0.004285  -1.552923                      11
# 4                -0.014993      -0.013100  -1.279426                      11
# ...                    ...            ...        ...                     ...
# 4313              0.005952      -0.013100  -0.504520                       3
# 4314              0.005952       0.004285   1.318788                       3
# 4315              0.005952      -0.013100   1.523910                       3
# 4316              0.005952      -0.013100   0.749004                       3
# 4317              0.005952       0.004285   0.862961                       3
#
#       dayofweek_Expected_checkin  stay  total_participants
# 0                              4     1                   6
# 1                              4     1                   3
# 2                              4     3                   4
# 3                              4     2                   6
# 4                              4     2                   4
# ...                          ...   ...                 ...
# 4313                           2     1                   7
# 4314                           2     3                   6
# 4315                           2     1                   5
# 4316                           2     1                   7
# 4317                           2     1                   5
#
# [4318 rows x 16 columns]

# %%
assert list(test_ds.iloc[:,1:].columns) == x_columns

# %%
x_test = np.asarray(test_ds.iloc[:,1:])

# %%
x_test
# Out:
# array([[ 5.24251095e-01,  1.03755526e-02, -1.41925334e-03, ...,
#          4.00000000e+00,  1.00000000e+00,  6.00000000e+00],
#        [ 1.97514996e-01,  1.03755526e-02, -1.41925334e-03, ...,
#          4.00000000e+00,  1.00000000e+00,  3.00000000e+00],
#        [-1.04408218e+00, -9.33960351e-03, -1.41925334e-03, ...,
#          4.00000000e+00,  3.00000000e+00,  4.00000000e+00],
#        ...,
#        [ 9.81681634e-01, -1.73146040e-02, -1.41925334e-03, ...,
#          2.00000000e+00,  1.00000000e+00,  5.00000000e+00],
#        [-6.38738835e-02,  1.43712890e-02, -3.17068265e-03, ...,
#          2.00000000e+00,  1.00000000e+00,  7.00000000e+00],
#        [-7.17346082e-01,  1.43712890e-02,  6.74556842e-03, ...,
#          2.00000000e+00,  1.00000000e+00,  5.00000000e+00]])

# %%
prediction_test = model.predict(x_test)

# %%
prediction_test = np.apply_along_axis(func, 1, prediction_test)

# %%
prediction_test
# Out:
# array([0, 2, 0, ..., 1, 0, 0], dtype=int64)

# %%
sub_df = pd.DataFrame()
sub_df['Reservation-id'] = test_ds.iloc[:, 0]
sub_df['Reservation_status'] = prediction_test+1

# %%
if 'predicts' not in os.listdir(NN_dir):
    os.mkdir(NN_dir+'predicts/')

# %%
sub_df.to_csv(NN_dir+'predicts/'+str(stats['test']['f1-score'])+'_.csv',index=False)
