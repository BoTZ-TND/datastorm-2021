# %%
import pandas as pd

# %%
pre_sub = pd.read_csv('../../data/model/submission3.csv')
nn_sub = pd.read_csv('../../data/model/sub_nn.csv')
cat_sub = pd.read_csv('../../data/model/submission3.csv')

# %%
pre_sub.head(20)
nn_sub.head(20)
cat_sub.head(20)
# Out:
#     Reservation-id  Reservation_status
# 0         62931593                   1
# 1         70586099                   1
# 2          4230648                   1
# 3         25192322                   1
# 4         80931528                   1
# 5         64700386                   1
# 6         16938050                   1
# 7         90487908                   1
# 8          5595445                   1
# 9         17502557                   1
# 10        92229895                   1
# 11        27386334                   1
# 12        76765181                   1
# 13        40697301                   1
# 14        63963888                   1
# 15        27282946                   1
# 16         8696141                   1
# 17        52621292                   1
# 18        21821230                   1
# 19        12316731                   1
#     Reservation-id  Reservation_status
# 0         62931593                   1
# 1         70586099                   1
# ...
