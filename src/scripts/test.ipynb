# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
main_dir = os.getenv('main_dir')

# %%
import os
import sys

module_path = os.path.abspath(os.path.join(main_dir,'scripts'))
if module_path not in sys.path:
    sys.path.append(module_path)
print(module_path)
from test import func
# Out:
# D:\Competitions\datastorm-2021\scripts
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-920ec598856a> in <module>
#       6     sys.path.append(module_path)
#       7 print(module_path)
# ----> 8 from test import func
#
# ImportError: cannot import name 'func' from 'test' (D:\Competitions\datastorm-2021\src\scripts\test.py)
