# %%
import numpy as np
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
main_dir = 'D:/Competitions/datastorm-2021'

# %%
data_dir = main_dir+'/data/data/'
train_file = data_dir+'train.csv'
val_file = data_dir+'validation.csv'
test_file = data_dir+'test.csv'

# %%
train_ds = pd.read_csv(train_file)
train_ds.dtypes
# Out:
# Reservation-id             int64
# Gender                    object
# Age                        int64
# Ethnicity                 object
# Educational_Level         object
# Income                    object
# Country_region            object
# Hotel_Type                object
# Expected_checkin          object
# Expected_checkout         object
# Booking_date              object
# Adults                     int64
# Children                   int64
# Babies                     int64
# Meal_Type                 object
# Visted_Previously         object
# Previous_Cancellations    object
# Deposit_type              object
# Booking_channel           object
# Required_Car_Parking      object
# Reservation_Status        object
# Use_Promotion             object
# Discount_Rate              int64
# Room_Rate                  int64
# dtype: object

# %%
categorical_columns = ['Gender','Age','Ethnicity','Educational_Level','Country_region','Meal_Type','Visted_Previously','Previous_Cancellations','Booking_channel','Required_Car_Parking','Use_Promotion','Reservation_Status']

def chi_congruency(df,columns):
    assert len(columns) == 2

    cross_tab = pd.crosstab(df[columns[0]],df[columns[1]],margins=True)
    columns_one = df[columns[0]].unique()
    columns_two = df[]
