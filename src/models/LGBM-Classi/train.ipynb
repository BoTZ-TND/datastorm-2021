# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import pandas as pd
import skopt
import sys
import os

# %%
def start_category_from_zero(df,columns):
    for each in columns:
        df[each] = df[each] - 1

    return df

# %%
SEARCH_PARAMS = {'learning_rate': 0.4,
                'max_depth': 15,
                'num_leaves': 32,
                'feature_fraction': 0.8,
                'subsample': 0.2}

FIXED_PARAMS={'objective': 'multiclass',
             'num_class':4,
             'metric': 'multi_logloss',
             'is_unbalance':True,
             'bagging_freq':5,
             'boosting':'dart',
             'num_boost_round':300,
             'early_stopping_rounds':30}

def train_evaluate(search_params):
   # you can download the dataset from this link(https://www.kaggle.com/c/santander-customer-transaction-prediction/data)
   # import Dataset to play with it
   data= pd.read_csv("../../../data/feature/cba_train.csv")
   start_category_from_zero(data,['Reservation_Status'])
   print(data['Reservation_Status'].unique())
   X = data.iloc[:, :-1]
   y = data.iloc[:, -1]
   X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=1234)
   train_data = lgb.Dataset(X_train, label=y_train)
   valid_data = lgb.Dataset(X_valid, label=y_valid, reference=train_data)

   params = {'metric':FIXED_PARAMS['metric'],
             'objective':FIXED_PARAMS['objective'],
             'num_class':FIXED_PARAMS['num_class'],
             **search_params}

   model = lgb.train(params, train_data,                     
                     valid_sets=[valid_data],
                     num_boost_round=FIXED_PARAMS['num_boost_round'],
                     early_stopping_rounds=FIXED_PARAMS['early_stopping_rounds'],
                     valid_names=['valid'])
   score = model.best_score['valid']['multi_logloss']
   return score

# %%
SPACE = [
   skopt.space.Real(0.01, 0.5, name='learning_rate', prior='log-uniform'),
   skopt.space.Integer(1, 30, name='max_depth'),
   skopt.space.Integer(10, 200, name='num_leaves'),
   skopt.space.Real(0.1, 1.0, name='feature_fraction', prior='uniform'),
   skopt.space.Real(0.1, 1.0, name='subsample', prior='uniform')
]
@skopt.utils.use_named_args(SPACE)
def objective(**params):
   return -1.0 * train_evaluate(params)

results = skopt.forest_minimize(objective, SPACE, 
                                n_calls=100, n_random_starts=10)
sk_utils.log_results(results)
# Out:
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000702 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.682711
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.680119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.679287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.679406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.676288
# [6]	valid's multi_logloss: 0.666256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.666449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.666636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.666508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.666878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.665995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.663547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.662485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.661084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.660561
# [16]	valid's multi_logloss: 0.658961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.658227
# [18]	valid's multi_logloss: 0.659566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.659455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.6593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.65856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.659062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.659142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.659117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.659608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.660305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.660142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.660156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.660703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.661397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.661652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.661787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.661643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.661841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.661663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.661655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid's multi_logloss: 0.661735
# [38]	valid's multi_logloss: 0.661755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid's multi_logloss: 0.662283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid's multi_logloss: 0.662599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid's multi_logloss: 0.662581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid's multi_logloss: 0.662908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid's multi_logloss: 0.663143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid's multi_logloss: 0.663826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid's multi_logloss: 0.664624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid's multi_logloss: 0.664983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid's multi_logloss: 0.665409
# Early stopping, best iteration is:
# [17]	valid's multi_logloss: 0.658227
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.687263
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.686596
# [3]	valid's multi_logloss: 0.685894
# [4]	valid's multi_logloss: 0.684823
# [5]	valid's multi_logloss: 0.683768
# [6]	valid's multi_logloss: 0.682792
# [7]	valid's multi_logloss: 0.682055
# [8]	valid's multi_logloss: 0.681482
# [9]	valid's multi_logloss: 0.680591
# [10]	valid's multi_logloss: 0.679587
# [11]	valid's multi_logloss: 0.678907
# [12]	valid's multi_logloss: 0.678083
# [13]	valid's multi_logloss: 0.677409
# [14]	valid's multi_logloss: 0.67671
# [15]	valid's multi_logloss: 0.676098
# [16]	valid's multi_logloss: 0.675448
# [17]	valid's multi_logloss: 0.674797
# [18]	valid's multi_logloss: 0.674043
# [19]	valid's multi_logloss: 0.673593
# [20]	valid's multi_logloss: 0.672821
# [21]	valid's multi_logloss: 0.672302
# [22]	valid's multi_logloss: 0.671734
# [23]	valid's multi_logloss: 0.671189
# [24]	valid's multi_logloss: 0.670739
# [25]	valid's multi_logloss: 0.670324
# [26]	valid's multi_logloss: 0.669604
# [27]	valid's multi_logloss: 0.66894
# [28]	valid's multi_logloss: 0.668408
# [29]	valid's multi_logloss: 0.667894
# [30]	valid's multi_logloss: 0.667486
# [31]	valid's multi_logloss: 0.66723
# [32]	valid's multi_logloss: 0.666881
# [33]	valid's multi_logloss: 0.666377
# [34]	valid's multi_logloss: 0.666084
# [35]	valid's multi_logloss: 0.665509
# [36]	valid's multi_logloss: 0.665076
# [37]	valid's multi_logloss: 0.664558
# [38]	valid's multi_logloss: 0.664181
# [39]	valid's multi_logloss: 0.663882
# [40]	valid's multi_logloss: 0.663397
# [41]	valid's multi_logloss: 0.663092
# [42]	valid's multi_logloss: 0.662784
# [43]	valid's multi_logloss: 0.662484
# [44]	valid's multi_logloss: 0.662213
# [45]	valid's multi_logloss: 0.66185
# [46]	valid's multi_logloss: 0.661561
# [47]	valid's multi_logloss: 0.66128
# [48]	valid's multi_logloss: 0.660907
# [49]	valid's multi_logloss: 0.660601
# [50]	valid's multi_logloss: 0.660226
# [51]	valid's multi_logloss: 0.659944
# [52]	valid's multi_logloss: 0.659622
# [53]	valid's multi_logloss: 0.659307
# [54]	valid's multi_logloss: 0.659093
# [55]	valid's multi_logloss: 0.658842
# [56]	valid's multi_logloss: 0.65849
# [57]	valid's multi_logloss: 0.658178
# [58]	valid's multi_logloss: 0.657912
# [59]	valid's multi_logloss: 0.657699
# [60]	valid's multi_logloss: 0.657406
# [61]	valid's multi_logloss: 0.657186
# [62]	valid's multi_logloss: 0.656939
# [63]	valid's multi_logloss: 0.656706
# [64]	valid's multi_logloss: 0.656491
# [65]	valid's multi_logloss: 0.656249
# [66]	valid's multi_logloss: 0.655977
# [67]	valid's multi_logloss: 0.655804
# [68]	valid's multi_logloss: 0.65569
# [69]	valid's multi_logloss: 0.655466
# [70]	valid's multi_logloss: 0.655207
# [71]	valid's multi_logloss: 0.655047
# [72]	valid's multi_logloss: 0.654905
# [73]	valid's multi_logloss: 0.654766
# [74]	valid's multi_logloss: 0.654613
# [75]	valid's multi_logloss: 0.654444
# [76]	valid's multi_logloss: 0.654313
# [77]	valid's multi_logloss: 0.654129
# [78]	valid's multi_logloss: 0.654041
# [79]	valid's multi_logloss: 0.653906
# [80]	valid's multi_logloss: 0.653798
# [81]	valid's multi_logloss: 0.653739
# [82]	valid's multi_logloss: 0.653646
# [83]	valid's multi_logloss: 0.653505
# [84]	valid's multi_logloss: 0.653431
# [85]	valid's multi_logloss: 0.653335
# [86]	valid's multi_logloss: 0.653299
# [87]	valid's multi_logloss: 0.653252
# [88]	valid's multi_logloss: 0.653145
# [89]	valid's multi_logloss: 0.653054
# [90]	valid's multi_logloss: 0.652984
# [91]	valid's multi_logloss: 0.652882
# [92]	valid's multi_logloss: 0.652815
# [93]	valid's multi_logloss: 0.652694
# [94]	valid's multi_logloss: 0.652542
# [95]	valid's multi_logloss: 0.652453
# [96]	valid's multi_logloss: 0.6524
# [97]	valid's multi_logloss: 0.652359
# [98]	valid's multi_logloss: 0.652254
# [99]	valid's multi_logloss: 0.652189
# [100]	valid's multi_logloss: 0.652134
# [101]	valid's multi_logloss: 0.652055
# [102]	valid's multi_logloss: 0.651988
# [103]	valid's multi_logloss: 0.651944
# [104]	valid's multi_logloss: 0.651858
# [105]	valid's multi_logloss: 0.651784
# [106]	valid's multi_logloss: 0.651727
# [107]	valid's multi_logloss: 0.651622
# [108]	valid's multi_logloss: 0.651493
# [109]	valid's multi_logloss: 0.651404
# [110]	valid's multi_logloss: 0.651267
# [111]	valid's multi_logloss: 0.651192
# [112]	valid's multi_logloss: 0.651118
# [113]	valid's multi_logloss: 0.651073
# [114]	valid's multi_logloss: 0.651025
# [115]	valid's multi_logloss: 0.650964
# [116]	valid's multi_logloss: 0.65091
# [117]	valid's multi_logloss: 0.650852
# [118]	valid's multi_logloss: 0.650838
# [119]	valid's multi_logloss: 0.650769
# [120]	valid's multi_logloss: 0.650676
# [121]	valid's multi_logloss: 0.650626
# [122]	valid's multi_logloss: 0.650548
# [123]	valid's multi_logloss: 0.650544
# [124]	valid's multi_logloss: 0.650442
# [125]	valid's multi_logloss: 0.650333
# [126]	valid's multi_logloss: 0.650305
# [127]	valid's multi_logloss: 0.650255
# [128]	valid's multi_logloss: 0.650203
# [129]	valid's multi_logloss: 0.650161
# [130]	valid's multi_logloss: 0.650108
# [131]	valid's multi_logloss: 0.650073
# [132]	valid's multi_logloss: 0.650028
# [133]	valid's multi_logloss: 0.649958
# [134]	valid's multi_logloss: 0.649946
# [135]	valid's multi_logloss: 0.649887
# [136]	valid's multi_logloss: 0.649852
# [137]	valid's multi_logloss: 0.649865
# [138]	valid's multi_logloss: 0.649826
# [139]	valid's multi_logloss: 0.649764
# [140]	valid's multi_logloss: 0.649723
# [141]	valid's multi_logloss: 0.649707
# [142]	valid's multi_logloss: 0.649692
# [143]	valid's multi_logloss: 0.649722
# [144]	valid's multi_logloss: 0.649711
# [145]	valid's multi_logloss: 0.649711
# [146]	valid's multi_logloss: 0.649722
# [147]	valid's multi_logloss: 0.649689
# [148]	valid's multi_logloss: 0.64966
# [149]	valid's multi_logloss: 0.649688
# [150]	valid's multi_logloss: 0.649704
# [151]	valid's multi_logloss: 0.649725
# [152]	valid's multi_logloss: 0.649729
# [153]	valid's multi_logloss: 0.649697
# [154]	valid's multi_logloss: 0.649696
# [155]	valid's multi_logloss: 0.649695
# [156]	valid's multi_logloss: 0.649714
# [157]	valid's multi_logloss: 0.649683
# [158]	valid's multi_logloss: 0.649699
# [159]	valid's multi_logloss: 0.649683
# [160]	valid's multi_logloss: 0.649679
# [161]	valid's multi_logloss: 0.649642
# [162]	valid's multi_logloss: 0.649645
# [163]	valid's multi_logloss: 0.649649
# [164]	valid's multi_logloss: 0.649613
# [165]	valid's multi_logloss: 0.649604
# [166]	valid's multi_logloss: 0.649596
# [167]	valid's multi_logloss: 0.649587
# [168]	valid's multi_logloss: 0.649581
# [169]	valid's multi_logloss: 0.649555
# [170]	valid's multi_logloss: 0.649575
# [171]	valid's multi_logloss: 0.64955
# [172]	valid's multi_logloss: 0.649533
# [173]	valid's multi_logloss: 0.64956
# [174]	valid's multi_logloss: 0.649541
# [175]	valid's multi_logloss: 0.649551
# [176]	valid's multi_logloss: 0.649537
# [177]	valid's multi_logloss: 0.649536
# [178]	valid's multi_logloss: 0.649488
# [179]	valid's multi_logloss: 0.649546
# [180]	valid's multi_logloss: 0.64956
# [181]	valid's multi_logloss: 0.649549
# [182]	valid's multi_logloss: 0.649571
# [183]	valid's multi_logloss: 0.649589
# [184]	valid's multi_logloss: 0.649612
# [185]	valid's multi_logloss: 0.649606
# [186]	valid's multi_logloss: 0.649613
# [187]	valid's multi_logloss: 0.649675
# [188]	valid's multi_logloss: 0.649657
# [189]	valid's multi_logloss: 0.649638
# [190]	valid's multi_logloss: 0.649612
# [191]	valid's multi_logloss: 0.649584
# [192]	valid's multi_logloss: 0.649614
# [193]	valid's multi_logloss: 0.649637
# [194]	valid's multi_logloss: 0.649632
# [195]	valid's multi_logloss: 0.649615
# [196]	valid's multi_logloss: 0.649617
# [197]	valid's multi_logloss: 0.649579
# [198]	valid's multi_logloss: 0.649638
# [199]	valid's multi_logloss: 0.649631
# [200]	valid's multi_logloss: 0.649616
# [201]	valid's multi_logloss: 0.649625
# [202]	valid's multi_logloss: 0.649647
# [203]	valid's multi_logloss: 0.649708
# [204]	valid's multi_logloss: 0.649706
# [205]	valid's multi_logloss: 0.649699
# [206]	valid's multi_logloss: 0.64974
# [207]	valid's multi_logloss: 0.64971
# [208]	valid's multi_logloss: 0.649754
# Early stopping, best iteration is:
# [178]	valid's multi_logloss: 0.649488
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000863 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.687352
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.686785
# [3]	valid's multi_logloss: 0.686131
# [4]	valid's multi_logloss: 0.685089
# [5]	valid's multi_logloss: 0.68411
# [6]	valid's multi_logloss: 0.683303
# [7]	valid's multi_logloss: 0.682661
# [8]	valid's multi_logloss: 0.682042
# [9]	valid's multi_logloss: 0.681173
# [10]	valid's multi_logloss: 0.680446
# [11]	valid's multi_logloss: 0.67982
# [12]	valid's multi_logloss: 0.679106
# [13]	valid's multi_logloss: 0.678566
# [14]	valid's multi_logloss: 0.677866
# [15]	valid's multi_logloss: 0.677315
# [16]	valid's multi_logloss: 0.676679
# [17]	valid's multi_logloss: 0.676156
# [18]	valid's multi_logloss: 0.675584
# [19]	valid's multi_logloss: 0.675135
# [20]	valid's multi_logloss: 0.674612
# [21]	valid's multi_logloss: 0.674216
# [22]	valid's multi_logloss: 0.673866
# [23]	valid's multi_logloss: 0.673431
# [24]	valid's multi_logloss: 0.673024
# [25]	valid's multi_logloss: 0.672669
# [26]	valid's multi_logloss: 0.672307
# [27]	valid's multi_logloss: 0.671923
# [28]	valid's multi_logloss: 0.671556
# [29]	valid's multi_logloss: 0.671199
# [30]	valid's multi_logloss: 0.670883
# [31]	valid's multi_logloss: 0.670581
# [32]	valid's multi_logloss: 0.670397
# [33]	valid's multi_logloss: 0.670097
# [34]	valid's multi_logloss: 0.669744
# [35]	valid's multi_logloss: 0.669451
# [36]	valid's multi_logloss: 0.669155
# [37]	valid's multi_logloss: 0.668874
# [38]	valid's multi_logloss: 0.668611
# [39]	valid's multi_logloss: 0.668354
# [40]	valid's multi_logloss: 0.668074
# [41]	valid's multi_logloss: 0.667798
# [42]	valid's multi_logloss: 0.667567
# [43]	valid's multi_logloss: 0.667335
# [44]	valid's multi_logloss: 0.667085
# [45]	valid's multi_logloss: 0.666871
# [46]	valid's multi_logloss: 0.666628
# [47]	valid's multi_logloss: 0.666396
# [48]	valid's multi_logloss: 0.666198
# [49]	valid's multi_logloss: 0.665997
# [50]	valid's multi_logloss: 0.665776
# [51]	valid's multi_logloss: 0.665568
# [52]	valid's multi_logloss: 0.665381
# [53]	valid's multi_logloss: 0.665208
# [54]	valid's multi_logloss: 0.66503
# [55]	valid's multi_logloss: 0.664865
# [56]	valid's multi_logloss: 0.664672
# [57]	valid's multi_logloss: 0.664509
# [58]	valid's multi_logloss: 0.664348
# [59]	valid's multi_logloss: 0.664191
# [60]	valid's multi_logloss: 0.664015
# [61]	valid's multi_logloss: 0.663866
# [62]	valid's multi_logloss: 0.663698
# [63]	valid's multi_logloss: 0.663558
# [64]	valid's multi_logloss: 0.663419
# [65]	valid's multi_logloss: 0.663244
# [66]	valid's multi_logloss: 0.663111
# [67]	valid's multi_logloss: 0.66299
# [68]	valid's multi_logloss: 0.662865
# [69]	valid's multi_logloss: 0.662723
# [70]	valid's multi_logloss: 0.662606
# [71]	valid's multi_logloss: 0.66247
# [72]	valid's multi_logloss: 0.662365
# [73]	valid's multi_logloss: 0.66226
# [74]	valid's multi_logloss: 0.662139
# [75]	valid's multi_logloss: 0.662031
# [76]	valid's multi_logloss: 0.661939
# [77]	valid's multi_logloss: 0.661835
# [78]	valid's multi_logloss: 0.661725
# [79]	valid's multi_logloss: 0.661625
# [80]	valid's multi_logloss: 0.661532
# [81]	valid's multi_logloss: 0.661437
# [82]	valid's multi_logloss: 0.661334
# [83]	valid's multi_logloss: 0.661241
# [84]	valid's multi_logloss: 0.661152
# [85]	valid's multi_logloss: 0.66106
# [86]	valid's multi_logloss: 0.660961
# [87]	valid's multi_logloss: 0.660881
# [88]	valid's multi_logloss: 0.660794
# [89]	valid's multi_logloss: 0.660719
# [90]	valid's multi_logloss: 0.660643
# [91]	valid's multi_logloss: 0.660566
# [92]	valid's multi_logloss: 0.660482
# [93]	valid's multi_logloss: 0.660386
# [94]	valid's multi_logloss: 0.660315
# [95]	valid's multi_logloss: 0.660225
# [96]	valid's multi_logloss: 0.660148
# [97]	valid's multi_logloss: 0.660077
# [98]	valid's multi_logloss: 0.660016
# [99]	valid's multi_logloss: 0.659942
# [100]	valid's multi_logloss: 0.659877
# [101]	valid's multi_logloss: 0.659813
# [102]	valid's multi_logloss: 0.659726
# [103]	valid's multi_logloss: 0.659669
# [104]	valid's multi_logloss: 0.659602
# [105]	valid's multi_logloss: 0.659541
# [106]	valid's multi_logloss: 0.659476
# [107]	valid's multi_logloss: 0.659413
# [108]	valid's multi_logloss: 0.659334
# [109]	valid's multi_logloss: 0.659265
# [110]	valid's multi_logloss: 0.65922
# [111]	valid's multi_logloss: 0.659167
# [112]	valid's multi_logloss: 0.659093
# [113]	valid's multi_logloss: 0.659032
# [114]	valid's multi_logloss: 0.658974
# [115]	valid's multi_logloss: 0.658921
# [116]	valid's multi_logloss: 0.658857
# [117]	valid's multi_logloss: 0.658801
# [118]	valid's multi_logloss: 0.658768
# [119]	valid's multi_logloss: 0.658712
# [120]	valid's multi_logloss: 0.658659
# [121]	valid's multi_logloss: 0.65861
# [122]	valid's multi_logloss: 0.658559
# [123]	valid's multi_logloss: 0.658508
# [124]	valid's multi_logloss: 0.658446
# [125]	valid's multi_logloss: 0.658397
# [126]	valid's multi_logloss: 0.658337
# [127]	valid's multi_logloss: 0.658292
# [128]	valid's multi_logloss: 0.658241
# [129]	valid's multi_logloss: 0.658195
# [130]	valid's multi_logloss: 0.658162
# [131]	valid's multi_logloss: 0.658117
# [132]	valid's multi_logloss: 0.658057
# [133]	valid's multi_logloss: 0.658017
# [134]	valid's multi_logloss: 0.657971
# [135]	valid's multi_logloss: 0.657919
# [136]	valid's multi_logloss: 0.65788
# [137]	valid's multi_logloss: 0.657833
# [138]	valid's multi_logloss: 0.657779
# [139]	valid's multi_logloss: 0.657734
# [140]	valid's multi_logloss: 0.657696
# [141]	valid's multi_logloss: 0.657654
# [142]	valid's multi_logloss: 0.657603
# [143]	valid's multi_logloss: 0.657564
# [144]	valid's multi_logloss: 0.657542
# [145]	valid's multi_logloss: 0.657493
# [146]	valid's multi_logloss: 0.65746
# [147]	valid's multi_logloss: 0.65741
# [148]	valid's multi_logloss: 0.657371
# [149]	valid's multi_logloss: 0.657327
# [150]	valid's multi_logloss: 0.657292
# [151]	valid's multi_logloss: 0.657254
# [152]	valid's multi_logloss: 0.657236
# [153]	valid's multi_logloss: 0.657202
# [154]	valid's multi_logloss: 0.65716
# [155]	valid's multi_logloss: 0.657121
# [156]	valid's multi_logloss: 0.657091
# [157]	valid's multi_logloss: 0.657055
# [158]	valid's multi_logloss: 0.657013
# [159]	valid's multi_logloss: 0.656974
# [160]	valid's multi_logloss: 0.656943
# [161]	valid's multi_logloss: 0.656909
# [162]	valid's multi_logloss: 0.656875
# [163]	valid's multi_logloss: 0.656842
# [164]	valid's multi_logloss: 0.656827
# [165]	valid's multi_logloss: 0.656797
# [166]	valid's multi_logloss: 0.656757
# [167]	valid's multi_logloss: 0.656725
# [168]	valid's multi_logloss: 0.656687
# [169]	valid's multi_logloss: 0.656648
# [170]	valid's multi_logloss: 0.656616
# [171]	valid's multi_logloss: 0.656598
# [172]	valid's multi_logloss: 0.65656
# [173]	valid's multi_logloss: 0.656528
# [174]	valid's multi_logloss: 0.656492
# [175]	valid's multi_logloss: 0.656452
# [176]	valid's multi_logloss: 0.65643
# [177]	valid's multi_logloss: 0.656392
# [178]	valid's multi_logloss: 0.656368
# [179]	valid's multi_logloss: 0.656343
# [180]	valid's multi_logloss: 0.656305
# [181]	valid's multi_logloss: 0.656291
# [182]	valid's multi_logloss: 0.656265
# [183]	valid's multi_logloss: 0.656234
# [184]	valid's multi_logloss: 0.656209
# [185]	valid's multi_logloss: 0.656184
# [186]	valid's multi_logloss: 0.656145
# [187]	valid's multi_logloss: 0.656119
# [188]	valid's multi_logloss: 0.656116
# [189]	valid's multi_logloss: 0.656081
# [190]	valid's multi_logloss: 0.656058
# [191]	valid's multi_logloss: 0.656025
# [192]	valid's multi_logloss: 0.656001
# [193]	valid's multi_logloss: 0.655975
# [194]	valid's multi_logloss: 0.655963
# [195]	valid's multi_logloss: 0.655941
# [196]	valid's multi_logloss: 0.655918
# [197]	valid's multi_logloss: 0.655898
# [198]	valid's multi_logloss: 0.655864
# [199]	valid's multi_logloss: 0.655831
# [200]	valid's multi_logloss: 0.655815
# [201]	valid's multi_logloss: 0.655797
# [202]	valid's multi_logloss: 0.65577
# [203]	valid's multi_logloss: 0.655748
# [204]	valid's multi_logloss: 0.655737
# [205]	valid's multi_logloss: 0.655709
# [206]	valid's multi_logloss: 0.655687
# [207]	valid's multi_logloss: 0.655674
# [208]	valid's multi_logloss: 0.655654
# [209]	valid's multi_logloss: 0.655629
# [210]	valid's multi_logloss: 0.655603
# [211]	valid's multi_logloss: 0.655577
# [212]	valid's multi_logloss: 0.655558
# [213]	valid's multi_logloss: 0.655554
# [214]	valid's multi_logloss: 0.655531
# [215]	valid's multi_logloss: 0.655519
# [216]	valid's multi_logloss: 0.655496
# [217]	valid's multi_logloss: 0.655467
# [218]	valid's multi_logloss: 0.655448
# [219]	valid's multi_logloss: 0.655427
# [220]	valid's multi_logloss: 0.655422
# [221]	valid's multi_logloss: 0.655395
# [222]	valid's multi_logloss: 0.655379
# [223]	valid's multi_logloss: 0.655364
# [224]	valid's multi_logloss: 0.65534
# [225]	valid's multi_logloss: 0.655332
# [226]	valid's multi_logloss: 0.655315
# [227]	valid's multi_logloss: 0.655286
# [228]	valid's multi_logloss: 0.655267
# [229]	valid's multi_logloss: 0.655252
# [230]	valid's multi_logloss: 0.655229
# [231]	valid's multi_logloss: 0.655214
# [232]	valid's multi_logloss: 0.655198
# [233]	valid's multi_logloss: 0.655185
# [234]	valid's multi_logloss: 0.655172
# [235]	valid's multi_logloss: 0.655152
# [236]	valid's multi_logloss: 0.65514
# [237]	valid's multi_logloss: 0.655115
# [238]	valid's multi_logloss: 0.655087
# [239]	valid's multi_logloss: 0.655074
# [240]	valid's multi_logloss: 0.655071
# [241]	valid's multi_logloss: 0.655052
# [242]	valid's multi_logloss: 0.655031
# [243]	valid's multi_logloss: 0.655015
# [244]	valid's multi_logloss: 0.655001
# [245]	valid's multi_logloss: 0.654987
# [246]	valid's multi_logloss: 0.654967
# [247]	valid's multi_logloss: 0.654953
# [248]	valid's multi_logloss: 0.654936
# [249]	valid's multi_logloss: 0.654919
# [250]	valid's multi_logloss: 0.6549
# [251]	valid's multi_logloss: 0.654883
# [252]	valid's multi_logloss: 0.654869
# [253]	valid's multi_logloss: 0.654855
# [254]	valid's multi_logloss: 0.654845
# [255]	valid's multi_logloss: 0.654823
# [256]	valid's multi_logloss: 0.65481
# [257]	valid's multi_logloss: 0.654788
# [258]	valid's multi_logloss: 0.65478
# [259]	valid's multi_logloss: 0.654767
# [260]	valid's multi_logloss: 0.654757
# [261]	valid's multi_logloss: 0.654742
# [262]	valid's multi_logloss: 0.654738
# [263]	valid's multi_logloss: 0.654715
# [264]	valid's multi_logloss: 0.654696
# [265]	valid's multi_logloss: 0.654678
# [266]	valid's multi_logloss: 0.654663
# [267]	valid's multi_logloss: 0.654647
# [268]	valid's multi_logloss: 0.654636
# [269]	valid's multi_logloss: 0.654617
# [270]	valid's multi_logloss: 0.654612
# [271]	valid's multi_logloss: 0.654599
# [272]	valid's multi_logloss: 0.654581
# [273]	valid's multi_logloss: 0.654567
# [274]	valid's multi_logloss: 0.654547
# [275]	valid's multi_logloss: 0.65453
# [276]	valid's multi_logloss: 0.654517
# [277]	valid's multi_logloss: 0.654508
# [278]	valid's multi_logloss: 0.654498
# [279]	valid's multi_logloss: 0.654482
# [280]	valid's multi_logloss: 0.654477
# [281]	valid's multi_logloss: 0.654465
# [282]	valid's multi_logloss: 0.654449
# [283]	valid's multi_logloss: 0.654434
# [284]	valid's multi_logloss: 0.654425
# [285]	valid's multi_logloss: 0.654412
# [286]	valid's multi_logloss: 0.654411
# [287]	valid's multi_logloss: 0.654393
# [288]	valid's multi_logloss: 0.654384
# [289]	valid's multi_logloss: 0.654368
# [290]	valid's multi_logloss: 0.654353
# [291]	valid's multi_logloss: 0.654352
# [292]	valid's multi_logloss: 0.654341
# [293]	valid's multi_logloss: 0.654327
# [294]	valid's multi_logloss: 0.654319
# [295]	valid's multi_logloss: 0.654301
# [296]	valid's multi_logloss: 0.65429
# [297]	valid's multi_logloss: 0.654292
# [298]	valid's multi_logloss: 0.654294
# [299]	valid's multi_logloss: 0.654282
# [300]	valid's multi_logloss: 0.654262
# Did not meet early stopping. Best iteration is:
# [300]	valid's multi_logloss: 0.654262
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000844 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.683529
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.681563
# [3]	valid's multi_logloss: 0.675233
# [4]	valid's multi_logloss: 0.672637
# [5]	valid's multi_logloss: 0.670816
# [6]	valid's multi_logloss: 0.667015
# [7]	valid's multi_logloss: 0.666451
# [8]	valid's multi_logloss: 0.666158
# [9]	valid's multi_logloss: 0.665492
# [10]	valid's multi_logloss: 0.663834
# [11]	valid's multi_logloss: 0.662652
# [12]	valid's multi_logloss: 0.661363
# [13]	valid's multi_logloss: 0.661526
# [14]	valid's multi_logloss: 0.6595
# [15]	valid's multi_logloss: 0.659076
# [16]	valid's multi_logloss: 0.659449
# [17]	valid's multi_logloss: 0.659275
# [18]	valid's multi_logloss: 0.659298
# [19]	valid's multi_logloss: 0.659487
# [20]	valid's multi_logloss: 0.659678
# [21]	valid's multi_logloss: 0.659934
# [22]	valid's multi_logloss: 0.659932
# [23]	valid's multi_logloss: 0.659684
# [24]	valid's multi_logloss: 0.659139
# [25]	valid's multi_logloss: 0.659414
# [26]	valid's multi_logloss: 0.659704
# [27]	valid's multi_logloss: 0.659424
# [28]	valid's multi_logloss: 0.659199
# [29]	valid's multi_logloss: 0.659451
# [30]	valid's multi_logloss: 0.659829
# [31]	valid's multi_logloss: 0.66002
# [32]	valid's multi_logloss: 0.660014
# [33]	valid's multi_logloss: 0.660065
# [34]	valid's multi_logloss: 0.659996
# [35]	valid's multi_logloss: 0.660389
# [36]	valid's multi_logloss: 0.660542
# [37]	valid's multi_logloss: 0.660876
# [38]	valid's multi_logloss: 0.661299
# [39]	valid's multi_logloss: 0.661617
# [40]	valid's multi_logloss: 0.661646
# [41]	valid's multi_logloss: 0.661953
# [42]	valid's multi_logloss: 0.662345
# [43]	valid's multi_logloss: 0.66249
# [44]	valid's multi_logloss: 0.6628
# [45]	valid's multi_logloss: 0.663161
# Early stopping, best iteration is:
# [15]	valid's multi_logloss: 0.659076
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.679973
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.676615
# [3]	valid's multi_logloss: 0.674446
# [4]	valid's multi_logloss: 0.668634
# [5]	valid's multi_logloss: 0.666684
# [6]	valid's multi_logloss: 0.66346
# [7]	valid's multi_logloss: 0.662666
# [8]	valid's multi_logloss: 0.661698
# [9]	valid's multi_logloss: 0.659644
# [10]	valid's multi_logloss: 0.657167
# [11]	valid's multi_logloss: 0.656917
# [12]	valid's multi_logloss: 0.656076
# [13]	valid's multi_logloss: 0.655437
# [14]	valid's multi_logloss: 0.654992
# [15]	valid's multi_logloss: 0.654517
# [16]	valid's multi_logloss: 0.654177
# [17]	valid's multi_logloss: 0.654229
# [18]	valid's multi_logloss: 0.653841
# [19]	valid's multi_logloss: 0.653481
# [20]	valid's multi_logloss: 0.653653
# [21]	valid's multi_logloss: 0.653335
# [22]	valid's multi_logloss: 0.653099
# [23]	valid's multi_logloss: 0.652825
# [24]	valid's multi_logloss: 0.653077
# [25]	valid's multi_logloss: 0.652889
# [26]	valid's multi_logloss: 0.652721
# [27]	valid's multi_logloss: 0.652861
# [28]	valid's multi_logloss: 0.652624
# [29]	valid's multi_logloss: 0.652763
# [30]	valid's multi_logloss: 0.652661
# [31]	valid's multi_logloss: 0.653134
# [32]	valid's multi_logloss: 0.65317
# [33]	valid's multi_logloss: 0.653605
# [34]	valid's multi_logloss: 0.653934
# [35]	valid's multi_logloss: 0.654112
# [36]	valid's multi_logloss: 0.654346
# [37]	valid's multi_logloss: 0.654395
# [38]	valid's multi_logloss: 0.654627
# [39]	valid's multi_logloss: 0.655254
# [40]	valid's multi_logloss: 0.655467
# [41]	valid's multi_logloss: 0.655913
# [42]	valid's multi_logloss: 0.655996
# [43]	valid's multi_logloss: 0.656397
# [44]	valid's multi_logloss: 0.656961
# [45]	valid's multi_logloss: 0.657377
# [46]	valid's multi_logloss: 0.657799
# [47]	valid's multi_logloss: 0.657716
# [48]	valid's multi_logloss: 0.658054
# [49]	valid's multi_logloss: 0.657871
# [50]	valid's multi_logloss: 0.65819
# [51]	valid's multi_logloss: 0.65815
# [52]	valid's multi_logloss: 0.658379
# [53]	valid's multi_logloss: 0.658312
# [54]	valid's multi_logloss: 0.658407
# [55]	valid's multi_logloss: 0.658616
# [56]	valid's multi_logloss: 0.658796
# [57]	valid's multi_logloss: 0.659212
# [58]	valid's multi_logloss: 0.659639
# Early stopping, best iteration is:
# [28]	valid's multi_logloss: 0.652624
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000806 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.685379
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.683543
# [3]	valid's multi_logloss: 0.681794
# [4]	valid's multi_logloss: 0.678869
# [5]	valid's multi_logloss: 0.676262
# [6]	valid's multi_logloss: 0.67427
# [7]	valid's multi_logloss: 0.67268
# [8]	valid's multi_logloss: 0.671364
# [9]	valid's multi_logloss: 0.669607
# [10]	valid's multi_logloss: 0.667998
# [11]	valid's multi_logloss: 0.666839
# [12]	valid's multi_logloss: 0.665518
# [13]	valid's multi_logloss: 0.664674
# [14]	valid's multi_logloss: 0.663325
# [15]	valid's multi_logloss: 0.662453
# [16]	valid's multi_logloss: 0.661589
# [17]	valid's multi_logloss: 0.660859
# [18]	valid's multi_logloss: 0.659864
# [19]	valid's multi_logloss: 0.659095
# [20]	valid's multi_logloss: 0.658236
# [21]	valid's multi_logloss: 0.657534
# [22]	valid's multi_logloss: 0.656949
# [23]	valid's multi_logloss: 0.656394
# [24]	valid's multi_logloss: 0.655915
# [25]	valid's multi_logloss: 0.655575
# [26]	valid's multi_logloss: 0.654991
# [27]	valid's multi_logloss: 0.65441
# [28]	valid's multi_logloss: 0.654224
# [29]	valid's multi_logloss: 0.653942
# [30]	valid's multi_logloss: 0.653519
# [31]	valid's multi_logloss: 0.653324
# [32]	valid's multi_logloss: 0.653425
# [33]	valid's multi_logloss: 0.653002
# [34]	valid's multi_logloss: 0.652868
# [35]	valid's multi_logloss: 0.652794
# [36]	valid's multi_logloss: 0.652751
# [37]	valid's multi_logloss: 0.652569
# [38]	valid's multi_logloss: 0.652477
# [39]	valid's multi_logloss: 0.652385
# [40]	valid's multi_logloss: 0.652395
# [41]	valid's multi_logloss: 0.652231
# [42]	valid's multi_logloss: 0.652164
# [43]	valid's multi_logloss: 0.652113
# [44]	valid's multi_logloss: 0.652042
# [45]	valid's multi_logloss: 0.651909
# [46]	valid's multi_logloss: 0.651819
# [47]	valid's multi_logloss: 0.65198
# [48]	valid's multi_logloss: 0.651987
# [49]	valid's multi_logloss: 0.651883
# [50]	valid's multi_logloss: 0.65172
# [51]	valid's multi_logloss: 0.651794
# [52]	valid's multi_logloss: 0.651743
# [53]	valid's multi_logloss: 0.651755
# [54]	valid's multi_logloss: 0.651803
# [55]	valid's multi_logloss: 0.651729
# [56]	valid's multi_logloss: 0.651738
# [57]	valid's multi_logloss: 0.651741
# [58]	valid's multi_logloss: 0.651589
# [59]	valid's multi_logloss: 0.651464
# [60]	valid's multi_logloss: 0.651361
# [61]	valid's multi_logloss: 0.651363
# [62]	valid's multi_logloss: 0.651572
# [63]	valid's multi_logloss: 0.651618
# [64]	valid's multi_logloss: 0.651729
# [65]	valid's multi_logloss: 0.65183
# [66]	valid's multi_logloss: 0.652012
# [67]	valid's multi_logloss: 0.652228
# [68]	valid's multi_logloss: 0.652172
# [69]	valid's multi_logloss: 0.652267
# [70]	valid's multi_logloss: 0.652435
# [71]	valid's multi_logloss: 0.652294
# [72]	valid's multi_logloss: 0.6525
# [73]	valid's multi_logloss: 0.652527
# [74]	valid's multi_logloss: 0.652636
# [75]	valid's multi_logloss: 0.652819
# [76]	valid's multi_logloss: 0.652897
# [77]	valid's multi_logloss: 0.653007
# [78]	valid's multi_logloss: 0.652976
# [79]	valid's multi_logloss: 0.65315
# [80]	valid's multi_logloss: 0.653302
# [81]	valid's multi_logloss: 0.653382
# [82]	valid's multi_logloss: 0.653428
# [83]	valid's multi_logloss: 0.653539
# [84]	valid's multi_logloss: 0.653533
# [85]	valid's multi_logloss: 0.653861
# [86]	valid's multi_logloss: 0.654048
# [87]	valid's multi_logloss: 0.654082
# [88]	valid's multi_logloss: 0.654055
# [89]	valid's multi_logloss: 0.654005
# [90]	valid's multi_logloss: 0.654104
# Early stopping, best iteration is:
# [60]	valid's multi_logloss: 0.651361
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000905 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.671624
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.666361
# [3]	valid's multi_logloss: 0.662406
# [4]	valid's multi_logloss: 0.659048
# [5]	valid's multi_logloss: 0.659507
# [6]	valid's multi_logloss: 0.65815
# [7]	valid's multi_logloss: 0.658984
# [8]	valid's multi_logloss: 0.658072
# [9]	valid's multi_logloss: 0.659232
# [10]	valid's multi_logloss: 0.659818
# [11]	valid's multi_logloss: 0.661094
# [12]	valid's multi_logloss: 0.661801
# [13]	valid's multi_logloss: 0.661525
# [14]	valid's multi_logloss: 0.66309
# [15]	valid's multi_logloss: 0.664038
# [16]	valid's multi_logloss: 0.665829
# [17]	valid's multi_logloss: 0.667114
# [18]	valid's multi_logloss: 0.668999
# [19]	valid's multi_logloss: 0.670039
# [20]	valid's multi_logloss: 0.671325
# [21]	valid's multi_logloss: 0.672563
# [22]	valid's multi_logloss: 0.673774
# [23]	valid's multi_logloss: 0.674415
# [24]	valid's multi_logloss: 0.675899
# [25]	valid's multi_logloss: 0.676971
# [26]	valid's multi_logloss: 0.678323
# [27]	valid's multi_logloss: 0.67994
# [28]	valid's multi_logloss: 0.681945
# [29]	valid's multi_logloss: 0.683807
# [30]	valid's multi_logloss: 0.684765
# [31]	valid's multi_logloss: 0.685965
# [32]	valid's multi_logloss: 0.686715
# [33]	valid's multi_logloss: 0.687843
# [34]	valid's multi_logloss: 0.689282
# [35]	valid's multi_logloss: 0.689769
# [36]	valid's multi_logloss: 0.689905
# [37]	valid's multi_logloss: 0.691267
# [38]	valid's multi_logloss: 0.692343
# Early stopping, best iteration is:
# [8]	valid's multi_logloss: 0.658072
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000905 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.673588
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.676336
# [3]	valid's multi_logloss: 0.677916
# [4]	valid's multi_logloss: 0.680716
# [5]	valid's multi_logloss: 0.684302
# [6]	valid's multi_logloss: 0.687863
# [7]	valid's multi_logloss: 0.692716
# [8]	valid's multi_logloss: 0.697171
# [9]	valid's multi_logloss: 0.70044
# [10]	valid's multi_logloss: 0.703098
# [11]	valid's multi_logloss: 0.705045
# [12]	valid's multi_logloss: 0.706607
# [13]	valid's multi_logloss: 0.709627
# [14]	valid's multi_logloss: 0.714356
# [15]	valid's multi_logloss: 0.718414
# [16]	valid's multi_logloss: 0.722349
# [17]	valid's multi_logloss: 0.724963
# [18]	valid's multi_logloss: 0.727198
# [19]	valid's multi_logloss: 0.733579
# [20]	valid's multi_logloss: 0.735987
# [21]	valid's multi_logloss: 0.737966
# [22]	valid's multi_logloss: 0.741235
# [23]	valid's multi_logloss: 0.745222
# [24]	valid's multi_logloss: 0.748739
# [25]	valid's multi_logloss: 0.753861
# [26]	valid's multi_logloss: 0.756693
# [27]	valid's multi_logloss: 0.760684
# [28]	valid's multi_logloss: 0.764778
# [29]	valid's multi_logloss: 0.768294
# [30]	valid's multi_logloss: 0.771172
# [31]	valid's multi_logloss: 0.775066
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 0.673588
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.6866
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid's multi_logloss: 0.685697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.685287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.685182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.684033
# [6]	valid's multi_logloss: 0.6794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.679435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.679396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.679119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.679209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.67863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.676663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.675411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.673593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.67318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.671196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.669662
# [18]	valid's multi_logloss: 0.66947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.669137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.669042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.668508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.667627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.666526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.666527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.666455
# [26]	valid's multi_logloss: 0.666849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.666535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.665651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.665621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.665764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.665792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.664945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.664411
# [34]	valid's multi_logloss: 0.664621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.664177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.663818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid's multi_logloss: 0.66383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid's multi_logloss: 0.663337
# ...
# [33]	valid's multi_logloss: 0.714872
# [34]	valid's multi_logloss: 0.716818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.719431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.720761
# [37]	valid's multi_logloss: 0.723802
# Early stopping, best iteration is:
# [7]	valid's multi_logloss: 0.675976
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000751 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.677731
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid's multi_logloss: 0.671274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.672523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.668747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.67185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid's multi_logloss: 0.671686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.674374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.676279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.680744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.681386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.6836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.685641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.686927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.687805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.691155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.69449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.696892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid's multi_logloss: 0.699204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.701051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.704591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.708112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.710653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.714609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.717195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.720001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.722542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.725432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.727367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.729101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.731829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.734365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.736828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.739801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.74205
# Early stopping, best iteration is:
# [4]	valid's multi_logloss: 0.668747
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001013 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.667076
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.668277
# [3]	valid's multi_logloss: 0.673399
# [4]	valid's multi_logloss: 0.677991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.682514
# [6]	valid's multi_logloss: 0.686986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.693258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.699031
# [9]	valid's multi_logloss: 0.703149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.708232
# [11]	valid's multi_logloss: 0.714114
# [12]	valid's multi_logloss: 0.719445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.725961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.730495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.734193
# [16]	valid's multi_logloss: 0.738011
# [17]	valid's multi_logloss: 0.744097
# [18]	valid's multi_logloss: 0.747986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.753795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.755976
# [21]	valid's multi_logloss: 0.763078
# [22]	valid's multi_logloss: 0.76775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.773235
# [24]	valid's multi_logloss: 0.779409
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.782086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.786074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.790598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.796309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.798616
# [30]	valid's multi_logloss: 0.801992
# [31]	valid's multi_logloss: 0.808952
# Early stopping, best iteration is:
# [1]	valid's multi_logloss: 0.667076
# [0 1 2]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000833 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Info] Start training from score -34.538776
# [1]	valid's multi_logloss: 0.685776
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.676782
# [3]	valid's multi_logloss: 0.675775
# [4]	valid's multi_logloss: 0.674264
# [5]	valid's multi_logloss: 0.674371
# [6]	valid's multi_logloss: 0.6687
# [7]	valid's multi_logloss: 0.666702
# [8]	valid's multi_logloss: 0.666633
# [9]	valid's multi_logloss: 0.665049
# [10]	valid's multi_logloss: 0.667136
# [11]	valid's multi_logloss: 0.667716
# [12]	valid's multi_logloss: 0.667628
# [13]	valid's multi_logloss: 0.66824
# [14]	valid's multi_logloss: 0.667684
# [15]	valid's multi_logloss: 0.668874
# [16]	valid's multi_logloss: 0.669985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.671102
# [18]	valid's multi_logloss: 0.670462
# [19]	valid's multi_logloss: 0.670166
# [20]	valid's multi_logloss: 0.671029
# [21]	valid's multi_logloss: 0.670712
# [22]	valid's multi_logloss: 0.671415
# [23]	valid's multi_logloss: 0.672285
# [24]	valid's multi_logloss: 0.672082
# [25]	valid's multi_logloss: 0.672894
# [26]	valid's multi_logloss: 0.673781
# [27]	valid's multi_logloss: 0.675216
# [28]	valid's multi_logloss: 0.675746
# [29]	valid's multi_logloss: 0.676063
# [30]	valid's multi_logloss: 0.67687
# [31]	valid's multi_logloss: 0.6776
# [32]	valid's multi_logloss: 0.678223
# [33]	valid's multi_logloss: 0.680028
# [34]	valid's multi_logloss: 0.68047
# [35]	valid's multi_logloss: 0.68065
# [36]	valid's multi_logloss: 0.681558
# [37]	valid's multi_logloss: 0.682675
# [38]	valid's multi_logloss: 0.683679
# [39]	valid's multi_logloss: 0.684983
# Early stopping, best iteration is:
# [9]	valid's multi_logloss: 0.665049
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3ac79aa3e53e> in <module>
#      12 results = skopt.forest_minimize(objective, SPACE,
#      13                                 n_calls=100, n_random_starts=10)
# ---> 14 sk_utils.log_results(results)
#      15
#      16
#
# NameError: name 'sk_utils' is not defined
