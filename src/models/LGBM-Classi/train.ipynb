# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import pandas as pd
import skopt
import sys
import os

# %%
SEARCH_PARAMS = {'learning_rate': 0.4,
                'max_depth': 15,
                'num_leaves': 32,
                'feature_fraction': 0.8,
                'subsample': 0.2}

FIXED_PARAMS={'objective': 'multiclass',
             'num_class':3,
             'metric': 'multi_logloss',
             'is_unbalance':True,
             'bagging_freq':5,
             'boosting':'dart',
             'num_boost_round':300,
             'early_stopping_rounds':30}

def train_evaluate(search_params):
   # you can download the dataset from this link(https://www.kaggle.com/c/santander-customer-transaction-prediction/data)
   # import Dataset to play with it
   data= pd.read_csv("../../../data/feature/cba_train.csv")
   X = data.iloc[:, :-1]
   y = data.iloc[:, -1]-1
   X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=1234)
   train_data = lgb.Dataset(X_train, label=y_train)
   valid_data = lgb.Dataset(X_valid, label=y_valid, reference=train_data)

   params = {'metric':FIXED_PARAMS['metric'],
             'objective':FIXED_PARAMS['objective'],
             'num_class':FIXED_PARAMS['num_class'],
             **search_params}

   model = lgb.train(params, train_data,                     
                     valid_sets=[valid_data],
                     num_boost_round=FIXED_PARAMS['num_boost_round'],
                     early_stopping_rounds=FIXED_PARAMS['early_stopping_rounds'],
                     valid_names=['valid'])
   score = model.best_score['valid']['multi_logloss']
   return score

# %%
SPACE = [
   skopt.space.Real(0.01, 0.5, name='learning_rate', prior='log-uniform'),
   skopt.space.Integer(1, 30, name='max_depth'),
   skopt.space.Integer(10, 200, name='num_leaves'),
   skopt.space.Real(0.1, 1.0, name='feature_fraction', prior='uniform'),
   skopt.space.Real(0.1, 1.0, name='subsample', prior='uniform')
]
@skopt.utils.use_named_args(SPACE)
def objective(**params):
   return -1.0 * train_evaluate(params)

results = skopt.forest_minimize(objective, SPACE, 
                                n_calls=100, n_random_starts=10)
sk_utils.log_results(results)
# Out:
# her splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.681053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.681266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.681591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.682332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.683562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.683777
# [37]	valid's multi_logloss: 0.685522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid's multi_logloss: 0.685067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid's multi_logloss: 0.685971
# Early stopping, best iteration is:
# [9]	valid's multi_logloss: 0.670955
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001578 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [1]	valid's multi_logloss: 0.68668
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.682039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.680851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.679536
# [5]	valid's multi_logloss: 0.678702
# [6]	valid's multi_logloss: 0.673886
# [7]	valid's multi_logloss: 0.671779
# [8]	valid's multi_logloss: 0.670409
# [9]	valid's multi_logloss: 0.668078
# [10]	valid's multi_logloss: 0.668662
# [11]	valid's multi_logloss: 0.668837
# [12]	valid's multi_logloss: 0.668122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.667861
# [14]	valid's multi_logloss: 0.667384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.66666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.666524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.666722
# [18]	valid's multi_logloss: 0.665039
# [19]	valid's multi_logloss: 0.664546
# [20]	valid's multi_logloss: 0.665104
# [21]	valid's multi_logloss: 0.663509
# [22]	valid's multi_logloss: 0.664551
# [23]	valid's multi_logloss: 0.664886
# [24]	valid's multi_logloss: 0.665088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.664983
# [26]	valid's multi_logloss: 0.664827
# [27]	valid's multi_logloss: 0.665228
# [28]	valid's multi_logloss: 0.666392
# [29]	valid's multi_logloss: 0.66669
# [30]	valid's multi_logloss: 0.667154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.667249
# [32]	valid's multi_logloss: 0.667879
# [33]	valid's multi_logloss: 0.667998
# [34]	valid's multi_logloss: 0.668368
# [35]	valid's multi_logloss: 0.668727
# [36]	valid's multi_logloss: 0.669092
# [37]	valid's multi_logloss: 0.669727
# [38]	valid's multi_logloss: 0.67038
# [39]	valid's multi_logloss: 0.670652
# [40]	valid's multi_logloss: 0.671158
# [41]	valid's multi_logloss: 0.671669
# [42]	valid's multi_logloss: 0.672241
# [43]	valid's multi_logloss: 0.672844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid's multi_logloss: 0.673272
# [45]	valid's multi_logloss: 0.673007
# [46]	valid's multi_logloss: 0.673284
# [47]	valid's multi_logloss: 0.674153
# [48]	valid's multi_logloss: 0.674949
# [49]	valid's multi_logloss: 0.674964
# [50]	valid's multi_logloss: 0.675646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid's multi_logloss: 0.675738
# Early stopping, best iteration is:
# [21]	valid's multi_logloss: 0.663509
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001849 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.684363
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.678958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.678213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.674113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.67406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid's multi_logloss: 0.672275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.671497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.672883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.670943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.671943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.673795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.673263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.674225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.673433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.672175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.672789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.671787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid's multi_logloss: 0.672758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.672963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.67373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.674966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.675027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.675614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.677736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.677709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.677873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.67881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.679113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.680301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.680634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.681157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.680995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.681334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.681437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.68231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.682545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid's multi_logloss: 0.684035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid's multi_logloss: 0.68407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid's multi_logloss: 0.685534
# Early stopping, best iteration is:
# [9]	valid's multi_logloss: 0.670943
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001312 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.680251
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid's multi_logloss: 0.677685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.677221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.67845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.67646
# [6]	valid's multi_logloss: 0.667627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.668116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.668799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.669527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.671349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.673585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.672378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.673311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.675434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.675558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.676811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.677737
# [18]	valid's multi_logloss: 0.682582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.683912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.684859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.686019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.688034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.689675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.690487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.692289
# [26]	valid's multi_logloss: 0.695896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.696933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.697944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.699627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.701195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.701618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.703728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.703786
# [34]	valid's multi_logloss: 0.707175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.707053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.707792
# Early stopping, best iteration is:
# [6]	valid's multi_logloss: 0.667627
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [1]	valid's multi_logloss: 0.681808
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.679779
# [3]	valid's multi_logloss: 0.671766
# [4]	valid's multi_logloss: 0.671529
# [5]	valid's multi_logloss: 0.676097
# [6]	valid's multi_logloss: 0.677072
# [7]	valid's multi_logloss: 0.679433
# [8]	valid's multi_logloss: 0.682087
# [9]	valid's multi_logloss: 0.683989
# [10]	valid's multi_logloss: 0.686675
# [11]	valid's multi_logloss: 0.688374
# [12]	valid's multi_logloss: 0.690064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.69116
# [14]	valid's multi_logloss: 0.694008
# [15]	valid's multi_logloss: 0.695243
# [16]	valid's multi_logloss: 0.696765
# [17]	valid's multi_logloss: 0.700744
# [18]	valid's multi_logloss: 0.703291
# [19]	valid's multi_logloss: 0.705217
# [20]	valid's multi_logloss: 0.708793
# [21]	valid's multi_logloss: 0.710972
# [22]	valid's multi_logloss: 0.712396
# [23]	valid's multi_logloss: 0.715733
# [24]	valid's multi_logloss: 0.718203
# [25]	valid's multi_logloss: 0.719706
# [26]	valid's multi_logloss: 0.722908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.725393
# [28]	valid's multi_logloss: 0.726851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.730144
# [30]	valid's multi_logloss: 0.735005
# [31]	valid's multi_logloss: 0.737723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.740427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.743886
# [34]	valid's multi_logloss: 0.74566
# Early stopping, best iteration is:
# [4]	valid's multi_logloss: 0.671529
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.68683
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid's multi_logloss: 0.676443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.675163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.674234
# [5]	valid's multi_logloss: 0.676336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid's multi_logloss: 0.671385
# [7]	valid's multi_logloss: 0.670716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.672555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.672056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.674296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.676807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.67876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.679913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.680352
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.681457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.683233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.684643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid's multi_logloss: 0.686173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.688554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.689338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.690174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.692616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.69407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.695842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.696732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.698875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.70048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.702218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.703689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.705944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.706794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.707508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.710232
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.711206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.712011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.714528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid's multi_logloss: 0.715868
# Early stopping, best iteration is:
# [7]	valid's multi_logloss: 0.670716
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid's multi_logloss: 0.683978
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid's multi_logloss: 0.678397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid's multi_logloss: 0.67791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid's multi_logloss: 0.673335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid's multi_logloss: 0.67321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid's multi_logloss: 0.671089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid's multi_logloss: 0.670566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid's multi_logloss: 0.671612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid's multi_logloss: 0.66976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid's multi_logloss: 0.6706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid's multi_logloss: 0.671468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid's multi_logloss: 0.670717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid's multi_logloss: 0.671687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid's multi_logloss: 0.671219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid's multi_logloss: 0.670599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid's multi_logloss: 0.671089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid's multi_logloss: 0.670165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid's multi_logloss: 0.671139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid's multi_logloss: 0.671578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid's multi_logloss: 0.672536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid's multi_logloss: 0.673853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid's multi_logloss: 0.674358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid's multi_logloss: 0.674422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid's multi_logloss: 0.675414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid's multi_logloss: 0.675475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid's multi_logloss: 0.676016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid's multi_logloss: 0.676397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid's multi_logloss: 0.676826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid's multi_logloss: 0.677521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid's multi_logloss: 0.677901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid's multi_logloss: 0.679676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid's multi_logloss: 0.67921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid's multi_logloss: 0.679427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid's multi_logloss: 0.679657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid's multi_logloss: 0.680491
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid's multi_logloss: 0.680572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid's multi_logloss: 0.682392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid's multi_logloss: 0.682194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid's multi_logloss: 0.683193
# Early stopping, best iteration is:
# [9]	valid's multi_logloss: 0.66976
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-573511f02a9c> in <module>
#      12 results = skopt.forest_minimize(objective, SPACE,
#      13                                 n_calls=100, n_random_starts=10)
# ---> 14 sk_utils.log_results(results)
#      15
#
# NameError: name 'sk_utils' is not defined

# %%
results
# Out:
#           fun: -0.6786117657008143
#     func_vals: array([-0.6530641 , -0.65685317, -0.65635307, -0.65316435, -0.65692355,
#        -0.65196275, -0.65161128, -0.65804859, -0.66451461, -0.66855338,
#        -0.66382629, -0.66847703, -0.6568113 , -0.65840178, -0.66998854,
#        -0.66089595, -0.65475082, -0.66331464, -0.6565183 , -0.65244418,
#        -0.66288576, -0.66657493, -0.65762524, -0.66951846, -0.67460179,
#        -0.67230352, -0.66128891, -0.6720062 , -0.66030552, -0.65774842,
#        -0.66860009, -0.65075282, -0.67349987, -0.66997205, -0.65902416,
#        -0.66758999, -0.66893929, -0.67428442, -0.65710855, -0.66651376,
#        -0.66681126, -0.67078525, -0.66707354, -0.67186868, -0.66803957,
#        -0.66726807, -0.66658572, -0.67028817, -0.66763558, -0.66782713,
#        -0.65018218, -0.6525538 , -0.66867195, -0.67480484, -0.67861177,
#        -0.67616935, -0.66650762, -0.6755459 , -0.65707761, -0.67440496,
#        -0.67411545, -0.67185391, -0.66702949, -0.67241269, -0.66516628,
#        -0.66653529, -0.66373202, -0.66459114, -0.66883928, -0.67456918,
#        -0.66052535, -0.66977973, -0.67229315, -0.66794966, -0.66846807,
#        -0.67681196, -0.66888091, -0.6727222 , -0.66773987, -0.66297312,
#        -0.67666304, -0.67483666, -0.67720239, -0.66592464, -0.67567487,
#        -0.67276174, -0.66807883, -0.65394443, -0.66756379, -0.66670884,
#        -0.67681203, -0.67136549, -0.67676503, -0.67095538, -0.66350899,
#        -0.67094292, -0.66762668, -0.67152942, -0.67071554, -0.66976027])
#        models: [ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=1853550231)]
#  random_state: RandomState(MT19937) at 0x1F1799DA378
#         space: Space([Real(low=0.01, high=0.5, prior='log-uniform', transform='identity'),
#        Integer(low=1, high=30, prior='uniform', transform='identity'),
#        Integer(low=10, high=200, prior='uniform', transform='identity'),
#        Real(low=0.1, high=1.0, prior='uniform', transform='identity'),
#        Real(low=0.1, high=1.0, prior='uniform', transform='identity')])
#         specs: {'args': {'func': <function objective at 0x000001F1136DC288>, 'dimensions': [Real(low=0.01, high=0.5, prior='log-uniform', transform='identity'), Integer(low=1, high=30, prior='uniform', transform='identity'), Integer(low=10, high=200, prior='uniform', transform='identity'), Real(low=0.1, high=1.0, prior='uniform', transform='identity'), Real(low=0.1, high=1.0, prior='uniform', transform='identity')], 'base_estimator': 'ET', 'n_calls': 100, 'n_random_starts': 10, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'EI', 'acq_optimizer': 'sampling', 'x0': None, 'y0': None, 'random_state': None, 'verbose': False, 'callback': None, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [0.48623869770130695, 13, 180, 0.28775932236001156, 0.6592301160630307]
#       x_iters: [[0.030286515821091913, 10, 166, 0.7586738687624605, 0.7085332415514655], [0.01985741742676309, 28, 155, 0.31256248492611455, 0.6723538447701101], [0.011648517769254024, 24, 111, 0.2686181554046414, 0.6881855392276603], [0.02030129087058157, 11, 37, 0.28245708961660687, 0.14057534228256724], [0.1542295838022765, 22, 183, 0.8753866752008964, 0.8922389532068837], [0.017463354780639255, 23, 175, 0.5492930823434249, 0.3327143730229273], [0.06467946400552148, 9, 75, 0.9969871629399398, 0.5187838037653725], [0.3334201546038173, 8, 79, 0.5943689908984315, 0.7173194291644854], [0.04648525925778078, 28, 200, 0.21314809094841977, 0.10766834585005108], [0.26254600869876366, 14, 199, 0.4489272600009323, 0.5002452419914674], [0.257539109227213, 18, 187, 0.4426759944606192, 0.1977517375162232], [0.17729336352908542, 8, 195, 0.13212941170129353, 0.3694939319344296], [0.12147235540088266, 7, 197, 0.3580267063702799, 0.23374170689132856], [0.18432001790282337, 9, 191, 0.1495537683104078, 0.6312542111104518], [0.49610218423509417, 21, 200, 0.7444725498663198, 0.4638069897588598], [0.3035969872267343, 18, 179, 0.9