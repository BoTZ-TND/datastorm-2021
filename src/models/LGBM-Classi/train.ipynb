# %%
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import pandas as pd
import skopt
import sys
import os

# %%
SEARCH_PARAMS = {'learning_rate': 0.4,
                'max_depth': 15,
                'num_leaves': 32,
                'feature_fraction': 0.8,
                'subsample': 0.2}

FIXED_PARAMS={'objective': 'multiclass',
             'num_class':4,
             'metric': 'multi_logloss',
             'is_unbalance':True,
             'bagging_freq':5,
             'boosting':'dart',
             'num_boost_round':300,
             'early_stopping_rounds':30}

def train_evaluate(search_params):
   # you can download the dataset from this link(https://www.kaggle.com/c/santander-customer-transaction-prediction/data)
   # import Dataset to play with it
   data= pd.read_csv("../../../data/feature/cba_train.csv")
   X = data.iloc[:, :-1]
   y = data.iloc[:, -1]
   X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=1234)
   train_data = lgb.Dataset(X_train, label=y_train)
   valid_data = lgb.Dataset(X_valid, label=y_valid, reference=train_data)

   params = {'metric':FIXED_PARAMS['metric'],
             'objective':FIXED_PARAMS['objective'],
             'num_class':FIXED_PARAMS['num_class'],
             **search_params}

   model = lgb.train(params, train_data,                     
                     valid_sets=[valid_data],
                     num_boost_round=FIXED_PARAMS['num_boost_round'],
                     early_stopping_rounds=FIXED_PARAMS['early_stopping_rounds'],
                     valid_names=['valid'])
   score = model.best_score['valid']['multi_logloss']
   return score

# %%
SPACE = [
   skopt.space.Real(0.01, 0.5, name='learning_rate', prior='log-uniform'),
   skopt.space.Integer(1, 30, name='max_depth'),
   skopt.space.Integer(10, 200, name='num_leaves'),
   skopt.space.Real(0.1, 1.0, name='feature_fraction', prior='uniform'),
   skopt.space.Real(0.1, 1.0, name='subsample', prior='uniform')
]
@skopt.utils.use_named_args(SPACE)
def objective(**params):
   return -1.0 * train_evaluate(params)

results = skopt.forest_minimize(objective, SPACE, 
                                n_calls=100, n_random_starts=10)
sk_utils.log_results(results)
# Out:
# ng] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid's multi_logloss: 0.679032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid's multi_logloss: 0.679006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid's multi_logloss: 0.679009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid's multi_logloss: 0.679007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid's multi_logloss: 0.678881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid's multi_logloss: 0.67888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid's multi_logloss: 0.678863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid's multi_logloss: 0.678788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid's multi_logloss: 0.678772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid's multi_logloss: 0.678756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid's multi_logloss: 0.678756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid's multi_logloss: 0.678745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid's multi_logloss: 0.678746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid's multi_logloss: 0.678749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid's multi_logloss: 0.678729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid's multi_logloss: 0.678735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid's multi_logloss: 0.678736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid's multi_logloss: 0.67867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid's multi_logloss: 0.678671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid's multi_logloss: 0.678641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid's multi_logloss: 0.678625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid's multi_logloss: 0.678616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid's multi_logloss: 0.678624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid's multi_logloss: 0.678624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid's multi_logloss: 0.678626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid's multi_logloss: 0.678592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid's multi_logloss: 0.678594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid's multi_logloss: 0.678464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid's multi_logloss: 0.678455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid's multi_logloss: 0.678417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid's multi_logloss: 0.678272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid's multi_logloss: 0.67826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid's multi_logloss: 0.678262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid's multi_logloss: 0.678242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid's multi_logloss: 0.678244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid's multi_logloss: 0.678225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid's multi_logloss: 0.678211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid's multi_logloss: 0.678211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid's multi_logloss: 0.678202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid's multi_logloss: 0.678202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid's multi_logloss: 0.678211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid's multi_logloss: 0.678182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid's multi_logloss: 0.678126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid's multi_logloss: 0.67812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid's multi_logloss: 0.678104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid's multi_logloss: 0.678045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid's multi_logloss: 0.678041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid's multi_logloss: 0.678041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid's multi_logloss: 0.67803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid's multi_logloss: 0.678018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid's multi_logloss: 0.678019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid's multi_logloss: 0.677999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid's multi_logloss: 0.678001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid's multi_logloss: 0.678001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid's multi_logloss: 0.677992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid's multi_logloss: 0.677996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid's multi_logloss: 0.678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid's multi_logloss: 0.677984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid's multi_logloss: 0.677985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid's multi_logloss: 0.677976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid's multi_logloss: 0.677986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid's multi_logloss: 0.677991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid's multi_logloss: 0.67799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid's multi_logloss: 0.677993
# [237]	valid's multi_logloss: 0.678005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid's multi_logloss: 0.677932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid's multi_logloss: 0.677915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid's multi_logloss: 0.677916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid's multi_logloss: 0.677914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid's multi_logloss: 0.677881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid's multi_logloss: 0.677874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid's multi_logloss: 0.677885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid's multi_logloss: 0.677885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid's multi_logloss: 0.677866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid's multi_logloss: 0.677839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid's multi_logloss: 0.677718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid's multi_logloss: 0.677709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid's multi_logloss: 0.677709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid's multi_logloss: 0.677648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid's multi_logloss: 0.677646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid's multi_logloss: 0.677648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid's multi_logloss: 0.677513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid's multi_logloss: 0.677518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid's multi_logloss: 0.677477
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid's multi_logloss: 0.677475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid's multi_logloss: 0.67748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid's multi_logloss: 0.67747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid's multi_logloss: 0.677471
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid's multi_logloss: 0.677473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid's multi_logloss: 0.677468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid's multi_logloss: 0.677476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid's multi_logloss: 0.677474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid's multi_logloss: 0.677332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid's multi_logloss: 0.677339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid's multi_logloss: 0.677327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid's multi_logloss: 0.677132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid's multi_logloss: 0.677135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid's multi_logloss: 0.67712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid's multi_logloss: 0.677109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid's multi_logloss: 0.677106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid's multi_logloss: 0.677107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid's multi_logloss: 0.677109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid's multi_logloss: 0.677104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid's multi_logloss: 0.677098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid's multi_logloss: 0.677095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid's multi_logloss: 0.677074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid's multi_logloss: 0.677074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid's multi_logloss: 0.677072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid's multi_logloss: 0.67707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid's multi_logloss: 0.677065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid's multi_logloss: 0.677007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid's multi_logloss: 0.676769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid's multi_logloss: 0.676772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid's multi_logloss: 0.676724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid's multi_logloss: 0.676726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid's multi_logloss: 0.676578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid's multi_logloss: 0.676566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid's multi_logloss: 0.676568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid's multi_logloss: 0.67656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid's multi_logloss: 0.676375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid's multi_logloss: 0.676189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid's multi_logloss: 0.676182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid's multi_logloss: 0.676186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid's multi_logloss: 0.676166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid's multi_logloss: 0.676166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid's multi_logloss: 0.676014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid's multi_logloss: 0.675804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid's multi_logloss: 0.675643
# Did not meet early stopping. Best iteration is:
# [300]	valid's multi_logloss: 0.675643
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001368 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 534
# [LightGBM] [Info] Number of data points in the train set: 21999, number of used features: 17
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Info] Start training from score -0.256960
# [LightGBM] [Info] Start training from score -1.902544
# [LightGBM] [Info] Start training from score -2.558606
# [1]	valid's multi_logloss: 0.688314
# Training until validation scores don't improve for 30 rounds
# [2]	valid's multi_logloss: 0.687875
# [3]	valid's multi_logloss: 0.687752
# [4]	valid's multi_logloss: 0.687594
# [5]	valid's multi_logloss: 0.687451
# [6]	valid's multi_logloss: 0.686856
# [7]	valid's multi_logloss: 0.686598
# [8]	valid's multi_logloss: 0.686268
# [9]	valid's multi_logloss: 0.685795
# [10]	valid's multi_logloss: 0.685648
# [11]	valid's multi_logloss: 0.68562
# [12]	valid's multi_logloss: 0.685282
# [13]	valid's multi_logloss: 0.685151
# [14]	valid's multi_logloss: 0.684932
# [15]	valid's multi_logloss: 0.684663
# [16]	valid's multi_logloss: 0.684627
# [17]	valid's multi_logloss: 0.68462
# [18]	valid's multi_logloss: 0.684151
# [19]	valid's multi_logloss: 0.683967
# [20]	valid's multi_logloss: 0.683818
# [21]	valid's multi_logloss: 0.683146
# [22]	valid's multi_logloss: 0.683169
# [23]	valid's multi_logloss: 0.682975
# [24]	valid's multi_logloss: 0.682794
# [25]	valid's multi_logloss: 0.682521
# [26]	valid's multi_logloss: 0.682113
# [27]	valid's multi_logloss: 0.681977
# [28]	valid's multi_logloss: 0.681865
# [29]	valid's multi_logloss: 0.681614
# [30]	valid's multi_logloss: 0.681551
# [31]	valid's multi_logloss: 0.681193
# [32]	valid's multi_logloss: 0.681008
# [33]	valid's multi_logloss: 0.680637
# [34]	valid's multi_logloss: 0.680171
# [35]	valid's multi_logloss: 0.679974
# [36]	valid's multi_logloss: 0.679824
# [37]	valid's multi_logloss: 0.679649
# [38]	valid's multi_logloss: 0.679352
# [39]	valid's multi_logloss: 0.678842
# [40]	valid's multi_logloss: 0.678577
# [41]	valid's multi_logloss: 0.678504
# [42]	valid's multi_logloss: 0.678235
# [43]	valid's multi_logloss: 0.678051
# [44]	valid's multi_logloss: 0.677702
# [45]	valid's multi_logloss: 0.677215
# [46]	valid's multi_logloss: 0.677123
# [47]	valid's multi_logloss: 0.676868
# [48]	valid's multi_logloss: 0.676858
# [49]	valid's multi_logloss: 0.676566
# [50]	valid's multi_logloss: 0.676347
# [51]	valid's multi_logloss: 0.676197
# [52]	valid's multi_logloss: 0.676016
# [53]	valid's multi_logloss: 0.675989
# [54]	valid's multi_logloss: 0.675616
# [55]	valid's multi_logloss: 0.675278
# [56]	valid's multi_logloss: 0.674999
# [57]	valid's multi_logloss: 0.674922
# [58]	valid's multi_logloss: 0.674785
# [59]	valid's multi_logloss: 0.674786
# [60]	valid's multi_logloss: 0.674552
# [61]	valid's multi_logloss: 0.674399
# [62]	valid's multi_logloss: 0.674044
# [63]	valid's multi_logloss: 0.673906
# [64]	valid's multi_logloss: 0.673607
# [65]	valid's multi_logloss: 0.67355
# [66]	valid's multi_logloss: 0.673334
# [67]	valid's multi_logloss: 0.673288
# [68]	valid's multi_logloss: 0.673211
# [69]	valid's multi_logloss: 0.673116
# [70]	valid's multi_logloss: 0.672843
# [71]	valid's multi_logloss: 0.672673
# [72]	valid's multi_logloss: 0.672468
# [73]	valid's multi_logloss: 0.672438
# [74]	valid's multi_logloss: 0.672278
# [75]	valid's multi_logloss: 0.672189
# [76]	valid's multi_logloss: 0.67189
# [77]	valid's multi_logloss: 0.671633
# [78]	valid's multi_logloss: 0.671515
# [79]	valid's multi_logloss: 0.671409
# [80]	valid's multi_logloss: 0.671276
# [81]	valid's multi_logloss: 0.671202
# [82]	valid's multi_logloss: 0.670893
# [83]	valid's multi_logloss: 0.670819
# [84]	valid's multi_logloss: 0.67063
# [85]	valid's multi_logloss: 0.67064
# [86]	valid's multi_logloss: 0.670402
# [87]	valid's multi_logloss: 0.670232
# [88]	valid's multi_logloss: 0.670001
# [89]	valid's multi_logloss: 0.66992
# [90]	valid's multi_logloss: 0.669784
# [91]	valid's multi_logloss: 0.669413
# [92]	valid's multi_logloss: 0.669241
# [93]	valid's multi_logloss: 0.669014
# [94]	valid's multi_logloss: 0.668896
# [95]	valid's multi_logloss: 0.668714
# [96]	valid's multi_logloss: 0.668464
# [97]	valid's multi_logloss: 0.668356
# [98]	valid's multi_logloss: 0.668206
# [99]	valid's multi_logloss: 0.668144
# [100]	valid's multi_logloss: 0.668031
# [101]	valid's multi_logloss: 0.667974
# [102]	valid's multi_logloss: 0.667848
# [103]	valid's multi_logloss: 0.66774
# [104]	valid's multi_logloss: 0.667596
# [105]	valid's multi_logloss: 0.667573
# [106]	valid's multi_logloss: 0.667444
# [107]	valid's multi_logloss: 0.667247
# [108]	valid's multi_logloss: 0.6671
# [109]	valid's multi_logloss: 0.666908
# [110]	valid's multi_logloss: 0.666809
# [111]	valid's multi_logloss: 0.666787
# [112]	valid's multi_logloss: 0.666649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid's multi_logloss: 0.666539
# [114]	valid's multi_logloss: 0.666409
# [115]	valid's multi_logloss: 0.666316
# [116]	valid's multi_logloss: 0.666205
# [117]	valid's multi_logloss: 0.666117
# [118]	valid's multi_logloss: 0.66605
# [119]	valid's multi_logloss: 0.665825
# [120]	valid's multi_logloss: 0.665735
# [121]	valid's multi_logloss: 0.665704
# [122]	valid's multi_logloss: 0.66547
# [123]	valid's multi_logloss: 0.665455
# [124]	valid's multi_logloss: 0.665192
# [125]	valid's multi_logloss: 0.6651
# [126]	valid's multi_logloss: 0.664883
# [127]	valid's multi_logloss: 0.664789
# [128]	valid's multi_logloss: 0.664777
# [129]	valid's multi_logloss: 0.664718
# [130]	valid's multi_logloss: 0.6646
# [131]	valid's multi_logloss: 0.664481
# [132]	valid's multi_logloss: 0.664442
# [133]	valid's multi_logloss: 0.664452
# [134]	valid's multi_logloss: 0.664364
# [135]	valid's multi_logloss: 0.664271
# [136]	valid's multi_logloss: 0.664198
# [137]	valid's multi_logloss: 0.664134
# [138]	valid's multi_logloss: 0.663966
# [139]	valid's multi_logloss: 0.663848
# [140]	valid's multi_logloss: 0.663771
# [141]	valid's multi_logloss: 0.663564
# [142]	valid's multi_logloss: 0.663366
# [143]	valid's multi_logloss: 0.663336
# [144]	valid's multi_logloss: 0.663328
# [145]	valid's multi_logloss: 0.663268
# [146]	valid's multi_logloss: 0.663174
# [147]	valid's multi_logloss: 0.663085
# [148]	valid's multi_logloss: 0.663085
# [149]	valid's multi_logloss: 0.663065
# [150]	valid's multi_logloss: 0.66285
# [151]	valid's multi_logloss: 0.662745
# [152]	valid's multi_logloss: 0.662636
# [153]	valid's multi_logloss: 0.66248
# [154]	valid's multi_logloss: 0.662439
# [155]	valid's multi_logloss: 0.662434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid's multi_logloss: 0.662422
# [157]	valid's multi_logloss: 0.662327
# [158]	valid's multi_logloss: 0.662196
# [159]	valid's multi_logloss: 0.662011
# [160]	valid's multi_logloss: 0.662041
# [161]	valid's multi_logloss: 0.661986
# [162]	valid's multi_logloss: 0.661846
# [163]	valid's multi_logloss: 0.661837
# [164]	valid's multi_logloss: 0.66178
# [165]	valid's multi_logloss: 0.661647
# [166]	valid's multi_logloss: 0.661617
# [167]	valid's multi_logloss: 0.66154
# [168]	valid's multi_logloss: 0.661496
# [169]	valid's multi_logloss: 0.661447
# [170]	valid's multi_logloss: 0.661378
# [171]	valid's multi_logloss: 0.661322
# [172]	valid's multi_logloss: 0.661243
# [173]	valid's multi_logloss: 0.661215
# [174]	valid's multi_logloss: 0.661044
# [175]	valid's multi_logloss: 0.660961
# [176]	valid's multi_logloss: 0.660934
# [177]	valid's multi_logloss: 0.660923
# [178]	valid's multi_logloss: 0.660716
# [179]	valid's multi_logloss: 0.660565
# [180]	valid's multi_logloss: 0.660576
# [181]	valid's multi_logloss: 0.660433
# [182]	valid's multi_logloss: 0.660389
# [183]	valid's multi_logloss: 0.660336
# [184]	valid's multi_logloss: 0.660162
# [185]	valid's multi_logloss: 0.660034
# [186]	valid's multi_logloss: 0.659933
# [187]	valid's multi_logloss: 0.659887
# [188]	valid's multi_logloss: 0.659787
# [189]	valid's multi_logloss: 0.659645
# [190]	valid's multi_logloss: 0.659621
# [191]	valid's multi_logloss: 0.659601
# [192]	valid's multi_logloss: 0.659621
# [193]	valid's multi_logloss: 0.659631
# [194]	valid's multi_logloss: 0.659572
# [195]	valid's multi_logloss: 0.659497
# [196]	valid's multi_logloss: 0.659477
# [197]	valid's multi_logloss: 0.659471
# [198]	valid's multi_logloss: 0.659402
# [199]	valid's multi_logloss: 0.659376
# [200]	valid's multi_logloss: 0.659303
# [201]	valid's multi_logloss: 0.659296
# [202]	valid's multi_logloss: 0.659228
# [203]	valid's multi_logloss: 0.659066
# [204]	valid's multi_logloss: 0.65906
# [205]	valid's multi_logloss: 0.658966
# [206]	valid's multi_logloss: 0.658944
# [207]	valid's multi_logloss: 0.658912
# [208]	valid's multi_logloss: 0.658864
# [209]	valid's multi_logloss: 0.658869
# [210]	valid's multi_logloss: 0.658794
# [211]	valid's multi_logloss: 0.658793
# [212]	valid's multi_logloss: 0.658776
# [213]	valid's multi_logloss: 0.658787
# [214]	valid's multi_logloss: 0.658717
# [215]	valid's multi_logloss: 0.658606
# [216]	valid's multi_logloss: 0.65844
# [217]	valid's multi_logloss: 0.658376
# [218]	valid's multi_logloss: 0.658274
# [219]	valid's multi_logloss: 0.658154
# [220]	valid's multi_logloss: 0.65815
# [221]	valid's multi_logloss: 0.658097
# [222]	valid's multi_logloss: 0.658052
# [223]	valid's multi_logloss: 0.657971
# [224]	valid's multi_logloss: 0.657924
# [225]	valid's multi_logloss: 0.657871
# [226]	valid's multi_logloss: 0.657842
# [227]	valid's multi_logloss: 0.657782
# [228]	valid's multi_logloss: 0.657744
# [229]	valid's multi_logloss: 0.657679
# [230]	valid's multi_logloss: 0.657601
# [231]	valid's multi_logloss: 0.657559
# [232]	valid's multi_logloss: 0.657518
# [233]	valid's multi_logloss: 0.657504
# [234]	valid's multi_logloss: 0.65745
# [235]	valid's multi_logloss: 0.657402
# [236]	valid's multi_logloss: 0.657408
# [237]	valid's multi_logloss: 0.65737
# [238]	valid's multi_logloss: 0.657341
# [239]	valid's multi_logloss: 0.657272
# [240]	valid's multi_logloss: 0.657217
# [241]	valid's multi_logloss: 0.65719
# [242]	valid's multi_logloss: 0.657114
# [243]	valid's multi_logloss: 0.657052
# [244]	valid's multi_logloss: 0.657059
# [245]	valid's multi_logloss: 0.657071
# [246]	valid's multi_logloss: 0.657053
# [247]	valid's multi_logloss: 0.656987
# [248]	valid's multi_logloss: 0.656946
# [249]	valid's multi_logloss: 0.656911
# [250]	valid's multi_logloss: 0.656879
# [251]	valid's multi_logloss: 0.656868
# [252]	valid's multi_logloss: 0.656866
# [253]	valid's multi_logloss: 0.656846
# [254]	valid's multi_logloss: 0.656796
# [255]	valid's multi_logloss: 0.656776
# [256]	valid's multi_logloss: 0.656771
# [257]	valid's multi_logloss: 0.656771
# [258]	valid's multi_logloss: 0.656705
# [259]	valid's multi_logloss: 0.656675
# [260]	valid's multi_logloss: 0.65662
# [261]	valid's multi_logloss: 0.656631
# [262]	valid's multi_logloss: 0.656619
# [263]	valid's multi_logloss: 0.656614
# [264]	valid's multi_logloss: 0.656578
# [265]	valid's multi_logloss: 0.656592
# [266]	valid's multi_logloss: 0.656585
# [267]	valid's multi_logloss: 0.656564
# [268]	valid's multi_logloss: 0.656514
# [269]	valid's multi_logloss: 0.656443
# [270]	valid's multi_logloss: 0.656401
# [271]	valid's multi_logloss: 0.656408
# [272]	valid's multi_logloss: 0.656379
# [273]	valid's multi_logloss: 0.656343
# [274]	valid's multi_logloss: 0.656241
# [275]	valid's multi_logloss: 0.656221
# [276]	valid's multi_logloss: 0.656232
# [277]	valid's multi_logloss: 0.656162
# [278]	valid's multi_logloss: 0.656174
# [279]	valid's multi_logloss: 0.656108
# [280]	valid's multi_logloss: 0.656039
# [281]	valid's multi_logloss: 0.656021
# [282]	valid's multi_logloss: 0.656002
# [283]	valid's multi_logloss: 0.655994
# [284]	valid's multi_logloss: 0.655931
# [285]	valid's multi_logloss: 0.655877
# [286]	valid's multi_logloss: 0.65587
# [287]	valid's multi_logloss: 0.655855
# [288]	valid's multi_logloss: 0.655788
# [289]	valid's multi_logloss: 0.655757
# [290]	valid's multi_logloss: 0.655744
# [291]	valid's multi_logloss: 0.655729
# [292]	valid's multi_logloss: 0.655724
# [293]	valid's multi_logloss: 0.65572
# [294]	valid's multi_logloss: 0.65568
# [295]	valid's multi_logloss: 0.655639
# [296]	valid's multi_logloss: 0.655602
# [297]	valid's multi_logloss: 0.655521
# [298]	valid's multi_logloss: 0.655482
# [299]	valid's multi_logloss: 0.655447
# [300]	valid's multi_logloss: 0.655417
# Did not meet early stopping. Best iteration is:
# [300]	valid's multi_logloss: 0.655417
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-573511f02a9c> in <module>
#      12 results = skopt.forest_minimize(objective, SPACE,
#      13                                 n_calls=100, n_random_starts=10)
# ---> 14 sk_utils.log_results(results)
#      15
#
# NameError: name 'sk_utils' is not defined
